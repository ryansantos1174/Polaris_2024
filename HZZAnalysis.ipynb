# %% [markdown]
# <CENTER><img src="../../images/ATLASOD.gif" style="width:50%"></CENTER>

# %% [markdown]
# # How to rediscover the Higgs boson yourself!
# This notebook uses ATLAS Open Data http://opendata.atlas.cern to show you the steps to rediscover the Higgs boson yourself!
#
# ATLAS Open Data provides open access to proton-proton collision data at the LHC for educational purposes. ATLAS Open Data resources are ideal for high-school, undergraduate and postgraduate students.
#
# Notebooks are web applications that allow you to create and share documents that can contain for example:
# 1. live code
# 2. visualisations
# 3. narrative text
#
# The idea is that cuts increase the ratio of signal ($H \rightarrow ZZ \rightarrow \ell\ell\ell\ell$) to background ($Z, t\bar{t}, ZZ \rightarrow \ell\ell\ell\ell$)
#
# First, the amount of $Z$ and $t\bar{t}$ background is reduced, since these are quite different to the signal.
#
# Then, the amount of $ZZ \rightarrow \ell\ell\ell\ell$ is reduced, whilst keeping as much $H \rightarrow ZZ \rightarrow \ell\ell\ell\ell$ signal as possible.
#
# The datasets used in this notebook have already been filtered to include at least 4 leptons per event, so that processing is quicker.
#
# This analysis loosely follows the [discovery of the Higgs boson by ATLAS](https://www.sciencedirect.com/science/article/pii/S037026931200857X) (mostly Section 4 and 4.1)
#
# By the end of this notebook you will be able to:
# 1. rediscover the Higgs boson yourself!
# 2. know some general principles of a particle physics analysis
#
# Feynman diagram pictures are borrowed from our friends at https://www.particlezoo.net

# %% [markdown]
# <CENTER><img src="images/feynman_diagrams/HZZ_feynman.png" style="width:40%"></CENTER>

# %% [markdown]
# <a id='contents'></a>

# %% [markdown]
# Contents:
#
# [Running a Jupyter notebook](#running) <br />
# [First time setup on your computer (no need on mybinder)](#setup_computer) <br />
# [To setup everytime](#setup_everytime) <br />
# [Lumi, fraction, file path](#fraction) <br />
# [Samples](#samples) <br />
# [Changing a cut](#changing_cut) <br />
# [Applying a cut](#applying_cut) <br />
# [Plotting](#plotting) <br />
# [What can you do to explore this analysis?](#going_further) <br />

# %% [markdown]
# <a id='running'></a>

# %% [markdown]
# ## Running a Jupyter notebook
#
# To run the whole Jupyter notebook, in the top menu click Cell -> Run All.
#
# To propagate a change you've made to a piece of code, click Cell -> Run All Below.
#
# You can also run a single code cell, by clicking Cell -> Run Cells, or using the keyboard shortcut Shift+Enter.

# %% [markdown]
# <a id='setup_computer'></a>

# %% [markdown]
# ## First time setup on your computer (no need on mybinder)
# This first cell only needs to be run the first time you open this notebook on your computer.
#
# If you close Jupyter and re-open on the same computer, you won't need to run this first cell again.
#
# If you open on mybinder, you don't need to run this cell.

# %%
import sys
import warnings
warnings.filterwarnings("ignore", category=FutureWarning) 

# update the pip package installer
# !{sys.executable} -m pip install --upgrade pip
# install required packages
# !{sys.executable} -m pip install --upgrade uproot awkward vector numpy matplotlib aiohttp requests awkward-pandas
# Out:
# Requirement already satisfied: pip in /home/ryan/.local/pipx/shared/lib/python3.11/site-packages (24.0)
# Requirement already satisfied: uproot in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (5.3.2)
# Requirement already satisfied: awkward in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (2.6.3)
# Requirement already satisfied: vector in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (1.3.1)
# Requirement already satisfied: numpy in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: matplotlib in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (3.8.3)
# Requirement already satisfied: aiohttp in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (3.9.3)
# Requirement already satisfied: requests in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (2.31.0)
# Requirement already satisfied: awkward-pandas in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (2023.8.0)
# Requirement already satisfied: cramjam>=2.5.0 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from uproot) (2.8.3)
# Requirement already satisfied: fsspec in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from uproot) (2024.3.1)
# Requirement already satisfied: packaging in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from uproot) (24.0)
# Requirement already satisfied: awkward-cpp==32 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from awkward) (32)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from awkward) (7.1.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: pillow>=8 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from aiohttp) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from aiohttp) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from aiohttp) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from aiohttp) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from aiohttp) (1.9.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from requests) (2024.2.2)
# Requirement already satisfied: pandas>=1.2 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from awkward-pandas) (1.4.4)
# Requirement already satisfied: zipp>=0.5 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from importlib-metadata>=4.13.0->awkward) (3.18.1)
# Requirement already satisfied: pytz>=2020.1 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from pandas>=1.2->awkward-pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /home/ryan/.local/pipx/venvs/jupyterlab/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='setup_everytime'></a>

# %% [markdown]
# ## To setup everytime
# Cell -> Run All Below
#
# to be done every time you re-open this notebook
#
# We're going to be using a number of tools to help us:
# * uproot: lets us read .root files typically used in particle physics into data formats used in python
# * awkward: lets us store data as awkward arrays, a format that generalizes numpy to nested data with possibly variable length lists
# * vector: to allow vectorized 4-momentum calculations
# * numpy: provides numerical calculations such as histogramming
# * matplotlib: common tool for making plots, figures, images, visualisations

# %%
import uproot # for reading .root files
import pickle
import pandas as pd # to represent nested data in columnar format
import vector # for 4-momentum calculations
import time # to measure time to analyse
import math # for mathematical functions such as square root
import numpy as np # for numerical calculations such as histogramming
import matplotlib.pyplot as plt # for plotting
from matplotlib.ticker import AutoMinorLocator # for minor ticks

import infofile # local file containing cross-sections, sums of weights, dataset IDs

with open("bdt_model.pkl", "rb") as file:
    bdt = pickle.load(file)
bdt.get_params()
# Out:
# {'algorithm': 'SAMME',
#  'estimator__ccp_alpha': 0.0,
#  'estimator__class_weight': None,
#  'estimator__criterion': 'gini',
#  'estimator__max_depth': 2,
#  'estimator__max_features': None,
#  'estimator__max_leaf_nodes': None,
#  'estimator__min_impurity_decrease': 0.0,
#  'estimator__min_samples_leaf': 1,
#  'estimator__min_samples_split': 2,
#  'estimator__min_weight_fraction_leaf': 0.0,
#  'estimator__monotonic_cst': None,
#  'estimator__random_state': None,
#  'estimator__splitter': 'best',
#  'estimator': DecisionTreeClassifier(max_depth=2),
#  'learning_rate': 0.5,
#  'n_estimators': 12,
#  'random_state': None}

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='fraction'></a>

# %% [markdown]
# ## Lumi, fraction, file path
#
# General definitions of fraction of data used, where to access the input files

# %%
#lumi = 0.5 # fb-1 # data_A only
#lumi = 1.9 # fb-1 # data_B only
#lumi = 2.9 # fb-1 # data_C only
#lumi = 4.7 # fb-1 # data_D only
lumi = 10 # fb-1 # data_A,data_B,data_C,data_D

fraction = 1 # reduce this is if you want the code to run quicker
                                                                                                                                  
#tuple_path = "Input/4lep/" # local 
tuple_path = "https://atlas-opendata.web.cern.ch/atlas-opendata/samples/2020/4lep/" # web address

# %% [markdown]
# <a id='samples'></a>

# %% [markdown]
# ## Samples
#
# samples to process

# %%
samples = {

    'data': {
        'list' : ['data_A','data_B','data_C','data_D'],
    },

    r'Background $Z,t\bar{t}$' : { # Z + ttbar
        'list' : ['Zee','Zmumu','ttbar_lep'],
        'color' : "#6b59d3" # purple
    },

    r'Background $ZZ^*$' : { # ZZ
        'list' : ['llll'],
        'color' : "#ff0000" # red
    },

    r'Signal ($m_H$ = 125 GeV)' : { # H -> ZZ -> llll
        'list' : ['ggH125_ZZ4lep','VBFH125_ZZ4lep','WH125_ZZ4lep','ZH125_ZZ4lep'],
        'color' : "#00cdff" # light blue
    },

}

# %% [markdown]
# Units, as stored in the data files

# %%
MeV = 0.001
GeV = 1.0

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# Define function to get data from files.
#
# The datasets used in this notebook have already been filtered to include at least 4 leptons per event, so that processing is quicker.

# %%
def get_data_from_files():

    data = {} # define empty dictionary to hold awkward arrays
    for s in samples: # loop over samples
        print('Processing '+s+' samples') # print which sample
        frames = [] # define empty list to hold data
        for val in samples[s]['list']: # loop over each file
            if s == 'data': prefix = "Data/" # Data prefix
            else: # MC prefix
                prefix = "MC/mc_"+str(infofile.infos[val]["DSID"])+"."
            fileString = tuple_path+prefix+val+".4lep.root" # file name to open
            temp = read_file(fileString,val) # call the function read_file defined below
            frames.append(temp) # append array returned from read_file to list of awkward arrays
        data[s] = pd.concat(frames) # dictionary entry is concatenated awkward arrays
    
    return data # return dictionary of awkward arrays

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# define function to calculate weight of MC event

# %%
def calc_weight(xsec_weight, events):
    return (
        xsec_weight
        * events.mcWeight
        * events.scaleFactor_PILEUP
        * events.scaleFactor_ELE
        * events.scaleFactor_MUON 
        * events.scaleFactor_LepTRIGGER
    )

# %% [markdown]
# define function to get cross-section weight

# %%
def get_xsec_weight(sample):
    info = infofile.infos[sample] # open infofile
    xsec_weight = (lumi*1000*info["xsec"])/(info["sumw"]*info["red_eff"]) #*1000 to go from fb-1 to pb-1
    return xsec_weight # return cross-section weight

# %% [markdown]
# define function to calculate 4-lepton invariant mass.
#
# Note: `lep_(pt|eta|phi|E)` are variable length lists of lepton momentum components for each event, represented by awkward arrays.

# %%
def calc_mllll(lep_pt, lep_eta, lep_phi, lep_E):
    # construct awkward 4-vector array
    p4 = vector.zip({"pt": lep_pt, "eta": lep_eta, "phi": lep_phi, "E": lep_E})
    # calculate invariant mass of first 4 leptons
    # [:, i] selects the i-th lepton in each event
    # .M calculates the invariant mass
    return (p4[:, 0] + p4[:, 1] + p4[:, 2] + p4[:, 3]).M * MeV

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='changing_cut'></a>

# %% [markdown]
# ## Changing a cut
#
# If you change a cut: Cell -> Run All Below
#
# If you change a cut here, you also need to make sure the cut is applied in the "[Applying a cut](#applying_cut)" cell.

# %%
# cut on lepton charge
# paper: "selecting two pairs of isolated leptons, each of which is comprised of two leptons with the same flavour and opposite charge"
def cut_lep_charge(lep_charge):
# throw away when sum of lepton charges is not equal to 0
# first lepton in each event is [:, 0], 2nd lepton is [:, 1] etc
    return lep_charge[:, 0] + lep_charge[:, 1] + lep_charge[:, 2] + lep_charge[:, 3] != 0

# cut on lepton type
# paper: "selecting two pairs of isolated leptons, each of which is comprised of two leptons with the same flavour and opposite charge"
def cut_lep_type(lep_type):
# for an electron lep_type is 11
# for a muon lep_type is 13
# throw away when none of eeee, mumumumu, eemumu
    sum_lep_type = lep_type[:, 0] + lep_type[:, 1] + lep_type[:, 2] + lep_type[:, 3]
    return (sum_lep_type != 44) & (sum_lep_type != 48) & (sum_lep_type != 52)

# Cut on BDT output
def cut_bdt_output(bdt_output, cutoff_value):
    return bdt_output < cutoff_value

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='applying_cut'></a>

# %% [markdown]
# ## Applying a cut
# If you add a cut: Cell -> Run All Below

# %%
def read_file(path,sample):
    start = time.time() # start the clock
    print("\tProcessing: "+sample) # print which sample is being processed
    data_all = pd.DataFrame() # define empty list to hold all data for this sample
    
    # open the tree called mini using a context manager (will automatically close files/resources)
    with uproot.open(path + ":mini") as tree:
        numevents = tree.num_entries # number of events
        if 'data' not in sample: xsec_weight = get_xsec_weight(sample) # get cross-section weight
        for data in tree.iterate(['lep_pt','lep_eta','lep_phi',
                                  'lep_E','lep_charge','lep_type', 
                                  # add more variables here if you make cuts on them 
                                  'mcWeight','scaleFactor_PILEUP',
                                  'scaleFactor_ELE','scaleFactor_MUON',
                                  'scaleFactor_LepTRIGGER'], # variables to calculate Monte Carlo weight
                                 library="pd", # choose output type as awkward array
                                 entry_stop=numevents*fraction): # process up to numevents*fraction

            nIn = len(data.index) # number of events in this batch

            if 'data' not in sample: # only do this for Monte Carlo simulation files
                # multiply all Monte Carlo weights and scale factors together to give total weight
                data['totalWeight'] = calc_weight(xsec_weight, data)

            
            
            # calculation of 4-lepton invariant mass using the function calc_mllll defined above
            data['mllll'] = calc_mllll(data.lep_pt, data.lep_eta, data.lep_phi, data.lep_E)

            # array contents can be printed at any stage like this
            #print(data)

            # array column can be printed at any stage like this
            #print(data['lep_pt'])

            # multiple array columns can be printed at any stage like this
            #print(data[['lep_pt','lep_eta']])

            nOut = len(data.index) # number of events passing cuts in this batch
            data_all = data_all.append(data) # append array from this batch
            elapsed = time.time() - start # time taken to process
            print("\t\t nIn: "+str(nIn)+",\t nOut: \t"+str(nOut)+"\t in "+str(round(elapsed,1))+"s") # events before and after
    
    return data_all # return array containing events passing all cuts

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# This is where the processing happens

# %%
start = time.time() # time at start of whole processing
data = get_data_from_files() # process all files
elapsed = time.time() - start # time after whole processing
print("Time taken: "+str(round(elapsed,1))+"s") # print total time taken to process every file
# Out:
# Processing data samples
# 	Processing: data_A
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 	Processing: data_B
# 		 nIn: 1,	 nOut: 	1	 in 0.7s
# 		 nIn: 1,	 nOut: 	1	 in 0.8s
# 		 nIn: 1,	 nOut: 	1	 in 0.8s
# 		 nIn: 1,	 nOut: 	1	 in 0.8s
# 		 nIn: 1,	 nOut: 	1	 in 0.8s
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.3s
# 		 nIn: 1,	 nOut: 	1	 in 3.3s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# 		 nIn: 1,	 nOut: 	1	 in 4.1s
# 		 nIn: 1,	 nOut: 	1	 in 4.1s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.6s
# 		 nIn: 1,	 nOut: 	1	 in 4.6s
# 		 nIn: 1,	 nOut: 	1	 in 4.7s
# 		 nIn: 1,	 nOut: 	1	 in 4.7s
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# 		 nIn: 1,	 nOut: 	1	 in 4.9s
# 		 nIn: 1,	 nOut: 	1	 in 4.9s
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# 		 nIn: 1,	 nOut: 	1	 in 5.2s
# 		 nIn: 1,	 nOut: 	1	 in 5.2s
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# 		 nIn: 1,	 nOut: 	1	 in 5.5s
# 		 nIn: 1,	 nOut: 	1	 in 5.5s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# 		 nIn: 1,	 nOut: 	1	 in 5.8s
# 		 nIn: 1,	 nOut: 	1	 in 5.8s
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# 		 nIn: 1,	 nOut: 	1	 in 6.0s
# 		 nIn: 1,	 nOut: 	1	 in 6.0s
# 		 nIn: 1,	 nOut: 	1	 in 6.1s
# 		 nIn: 1,	 nOut: 	1	 in 6.1s
# 		 nIn: 1,	 nOut: 	1	 in 6.2s
# 		 nIn: 1,	 nOut: 	1	 in 6.2s
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# 		 nIn: 1,	 nOut: 	1	 in 6.4s
# 		 nIn: 1,	 nOut: 	1	 in 6.4s
# 		 nIn: 1,	 nOut: 	1	 in 6.5s
# 		 nIn: 1,	 nOut: 	1	 in 6.5s
# 		 nIn: 1,	 nOut: 	1	 in 6.6s
# 	Processing: data_C
# 		 nIn: 1,	 nOut: 	1	 in 0.8s
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# 		 nIn: 1,	 nOut: 	1	 in 0.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.3s
# 		 nIn: 1,	 nOut: 	1	 in 3.3s
# 		 nIn: 1,	 nOut: 	1	 in 3.3s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# 		 nIn: 1,	 nOut: 	1	 in 4.1s
# 		 nIn: 1,	 nOut: 	1	 in 4.1s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.6s
# 		 nIn: 1,	 nOut: 	1	 in 4.6s
# 		 nIn: 1,	 nOut: 	1	 in 4.7s
# 		 nIn: 1,	 nOut: 	1	 in 4.7s
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# 		 nIn: 1,	 nOut: 	1	 in 4.9s
# 		 nIn: 1,	 nOut: 	1	 in 4.9s
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# 		 nIn: 1,	 nOut: 	1	 in 5.2s
# 		 nIn: 1,	 nOut: 	1	 in 5.2s
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# 		 nIn: 1,	 nOut: 	1	 in 5.5s
# 		 nIn: 1,	 nOut: 	1	 in 5.5s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# 		 nIn: 1,	 nOut: 	1	 in 5.8s
# 		 nIn: 1,	 nOut: 	1	 in 5.8s
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# 		 nIn: 1,	 nOut: 	1	 in 6.0s
# 		 nIn: 1,	 nOut: 	1	 in 6.0s
# 		 nIn: 1,	 nOut: 	1	 in 6.1s
# 		 nIn: 1,	 nOut: 	1	 in 6.1s
# 		 nIn: 1,	 nOut: 	1	 in 6.2s
# 		 nIn: 1,	 nOut: 	1	 in 6.2s
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# 		 nIn: 1,	 nOut: 	1	 in 6.4s
# 		 nIn: 1,	 nOut: 	1	 in 6.4s
# 		 nIn: 1,	 nOut: 	1	 in 6.5s
# 		 nIn: 1,	 nOut: 	1	 in 6.5s
# 		 nIn: 1,	 nOut: 	1	 in 6.6s
# 		 nIn: 1,	 nOut: 	1	 in 6.6s
# 		 nIn: 1,	 nOut: 	1	 in 6.7s
# 		 nIn: 1,	 nOut: 	1	 in 6.7s
# 		 nIn: 1,	 nOut: 	1	 in 6.8s
# 		 nIn: 1,	 nOut: 	1	 in 6.8s
# 		 nIn: 1,	 nOut: 	1	 in 6.9s
# 		 nIn: 1,	 nOut: 	1	 in 6.9s
# 		 nIn: 1,	 nOut: 	1	 in 7.0s
# 		 nIn: 1,	 nOut: 	1	 in 7.0s
# 		 nIn: 1,	 nOut: 	1	 in 7.1s
# 		 nIn: 1,	 nOut: 	1	 in 7.1s
# 		 nIn: 1,	 nOut: 	1	 in 7.2s
# 		 nIn: 1,	 nOut: 	1	 in 7.2s
# 		 nIn: 1,	 nOut: 	1	 in 7.3s
# 		 nIn: 1,	 nOut: 	1	 in 7.4s
# 		 nIn: 1,	 nOut: 	1	 in 7.4s
# 		 nIn: 1,	 nOut: 	1	 in 7.5s
# 		 nIn: 1,	 nOut: 	1	 in 7.5s
# 		 nIn: 1,	 nOut: 	1	 in 7.6s
# 		 nIn: 1,	 nOut: 	1	 in 7.6s
# 		 nIn: 1,	 nOut: 	1	 in 7.7s
# 		 nIn: 1,	 nOut: 	1	 in 7.7s
# 		 nIn: 1,	 nOut: 	1	 in 7.8s
# 		 nIn: 1,	 nOut: 	1	 in 7.8s
# 		 nIn: 1,	 nOut: 	1	 in 7.9s
# 		 nIn: 1,	 nOut: 	1	 in 7.9s
# 		 nIn: 1,	 nOut: 	1	 in 8.0s
# 		 nIn: 1,	 nOut: 	1	 in 8.1s
# 		 nIn: 1,	 nOut: 	1	 in 8.1s
# 		 nIn: 1,	 nOut: 	1	 in 8.2s
# 		 nIn: 1,	 nOut: 	1	 in 8.2s
# 		 nIn: 1,	 nOut: 	1	 in 8.3s
# 		 nIn: 1,	 nOut: 	1	 in 8.3s
# 		 nIn: 1,	 nOut: 	1	 in 8.4s
# 		 nIn: 1,	 nOut: 	1	 in 8.4s
# 		 nIn: 1,	 nOut: 	1	 in 8.5s
# 		 nIn: 1,	 nOut: 	1	 in 8.6s
# 		 nIn: 1,	 nOut: 	1	 in 8.6s
# 		 nIn: 1,	 nOut: 	1	 in 8.7s
# 		 nIn: 1,	 nOut: 	1	 in 8.7s
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# 		 nIn: 1,	 nOut: 	1	 in 8.9s
# 		 nIn: 1,	 nOut: 	1	 in 9.0s
# 		 nIn: 1,	 nOut: 	1	 in 9.0s
# 		 nIn: 1,	 nOut: 	1	 in 9.1s
# 		 nIn: 1,	 nOut: 	1	 in 9.1s
# 		 nIn: 1,	 nOut: 	1	 in 9.2s
# 		 nIn: 1,	 nOut: 	1	 in 9.3s
# 		 nIn: 1,	 nOut: 	1	 in 9.3s
# 		 nIn: 1,	 nOut: 	1	 in 9.4s
# 		 nIn: 1,	 nOut: 	1	 in 9.4s
# 		 nIn: 1,	 nOut: 	1	 in 9.5s
# 		 nIn: 1,	 nOut: 	1	 in 9.5s
# 		 nIn: 1,	 nOut: 	1	 in 9.6s
# 		 nIn: 1,	 nOut: 	1	 in 9.7s
# 		 nIn: 1,	 nOut: 	1	 in 9.7s
# 		 nIn: 1,	 nOut: 	1	 in 9.8s
# 		 nIn: 1,	 nOut: 	1	 in 9.8s
# 		 nIn: 1,	 nOut: 	1	 in 9.9s
# 		 nIn: 1,	 nOut: 	1	 in 10.0s
# 		 nIn: 1,	 nOut: 	1	 in 10.0s
# 		 nIn: 1,	 nOut: 	1	 in 10.1s
# 		 nIn: 1,	 nOut: 	1	 in 10.1s
# 		 nIn: 1,	 nOut: 	1	 in 10.2s
# 		 nIn: 1,	 nOut: 	1	 in 10.3s
# 		 nIn: 1,	 nOut: 	1	 in 10.3s
# 		 nIn: 1,	 nOut: 	1	 in 10.4s
# 		 nIn: 1,	 nOut: 	1	 in 10.4s
# 		 nIn: 1,	 nOut: 	1	 in 10.5s
# 		 nIn: 1,	 nOut: 	1	 in 10.6s
# 		 nIn: 1,	 nOut: 	1	 in 10.6s
# 		 nIn: 1,	 nOut: 	1	 in 10.7s
# 		 nIn: 1,	 nOut: 	1	 in 10.8s
# 		 nIn: 1,	 nOut: 	1	 in 10.8s
# 		 nIn: 1,	 nOut: 	1	 in 10.9s
# 		 nIn: 1,	 nOut: 	1	 in 10.9s
# 		 nIn: 1,	 nOut: 	1	 in 11.0s
# 		 nIn: 1,	 nOut: 	1	 in 11.1s
# 		 nIn: 1,	 nOut: 	1	 in 11.1s
# 		 nIn: 1,	 nOut: 	1	 in 11.2s
# 		 nIn: 1,	 nOut: 	1	 in 11.3s
# 	Processing: data_D
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.0s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.1s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.2s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.3s
# 		 nIn: 1,	 nOut: 	1	 in 3.3s
# 		 nIn: 1,	 nOut: 	1	 in 3.3s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# 		 nIn: 1,	 nOut: 	1	 in 4.1s
# 		 nIn: 1,	 nOut: 	1	 in 4.1s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.6s
# 		 nIn: 1,	 nOut: 	1	 in 4.6s
# 		 nIn: 1,	 nOut: 	1	 in 4.7s
# 		 nIn: 1,	 nOut: 	1	 in 4.7s
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# 		 nIn: 1,	 nOut: 	1	 in 4.9s
# 		 nIn: 1,	 nOut: 	1	 in 4.9s
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# 		 nIn: 1,	 nOut: 	1	 in 5.2s
# 		 nIn: 1,	 nOut: 	1	 in 5.2s
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# 		 nIn: 1,	 nOut: 	1	 in 5.5s
# 		 nIn: 1,	 nOut: 	1	 in 5.5s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# 		 nIn: 1,	 nOut: 	1	 in 5.8s
# 		 nIn: 1,	 nOut: 	1	 in 5.8s
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# 		 nIn: 1,	 nOut: 	1	 in 6.0s
# 		 nIn: 1,	 nOut: 	1	 in 6.0s
# 		 nIn: 1,	 nOut: 	1	 in 6.1s
# 		 nIn: 1,	 nOut: 	1	 in 6.1s
# 		 nIn: 1,	 nOut: 	1	 in 6.2s
# 		 nIn: 1,	 nOut: 	1	 in 6.2s
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# 		 nIn: 1,	 nOut: 	1	 in 6.4s
# 		 nIn: 1,	 nOut: 	1	 in 6.4s
# 		 nIn: 1,	 nOut: 	1	 in 6.5s
# 		 nIn: 1,	 nOut: 	1	 in 6.5s
# 		 nIn: 1,	 nOut: 	1	 in 6.6s
# 		 nIn: 1,	 nOut: 	1	 in 6.6s
# 		 nIn: 1,	 nOut: 	1	 in 6.7s
# 		 nIn: 1,	 nOut: 	1	 in 6.7s
# 		 nIn: 1,	 nOut: 	1	 in 6.8s
# 		 nIn: 1,	 nOut: 	1	 in 6.8s
# 		 nIn: 1,	 nOut: 	1	 in 6.9s
# 		 nIn: 1,	 nOut: 	1	 in 6.9s
# 		 nIn: 1,	 nOut: 	1	 in 7.0s
# 		 nIn: 1,	 nOut: 	1	 in 7.0s
# 		 nIn: 1,	 nOut: 	1	 in 7.1s
# 		 nIn: 1,	 nOut: 	1	 in 7.1s
# 		 nIn: 1,	 nOut: 	1	 in 7.2s
# 		 nIn: 1,	 nOut: 	1	 in 7.2s
# 		 nIn: 1,	 nOut: 	1	 in 7.3s
# 		 nIn: 1,	 nOut: 	1	 in 7.3s
# 		 nIn: 1,	 nOut: 	1	 in 7.4s
# 		 nIn: 1,	 nOut: 	1	 in 7.4s
# 		 nIn: 1,	 nOut: 	1	 in 7.5s
# 		 nIn: 1,	 nOut: 	1	 in 7.6s
# 		 nIn: 1,	 nOut: 	1	 in 7.6s
# 		 nIn: 1,	 nOut: 	1	 in 7.7s
# 		 nIn: 1,	 nOut: 	1	 in 7.7s
# 		 nIn: 1,	 nOut: 	1	 in 7.8s
# 		 nIn: 1,	 nOut: 	1	 in 7.8s
# 		 nIn: 1,	 nOut: 	1	 in 7.9s
# 		 nIn: 1,	 nOut: 	1	 in 7.9s
# 		 nIn: 1,	 nOut: 	1	 in 8.0s
# 		 nIn: 1,	 nOut: 	1	 in 8.0s
# 		 nIn: 1,	 nOut: 	1	 in 8.1s
# 		 nIn: 1,	 nOut: 	1	 in 8.1s
# 		 nIn: 1,	 nOut: 	1	 in 8.2s
# 		 nIn: 1,	 nOut: 	1	 in 8.3s
# 		 nIn: 1,	 nOut: 	1	 in 8.3s
# 		 nIn: 1,	 nOut: 	1	 in 8.4s
# 		 nIn: 1,	 nOut: 	1	 in 8.4s
# 		 nIn: 1,	 nOut: 	1	 in 8.5s
# 		 nIn: 1,	 nOut: 	1	 in 8.5s
# 		 nIn: 1,	 nOut: 	1	 in 8.6s
# 		 nIn: 1,	 nOut: 	1	 in 8.6s
# 		 nIn: 1,	 nOut: 	1	 in 8.7s
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# 		 nIn: 1,	 nOut: 	1	 in 8.9s
# 		 nIn: 1,	 nOut: 	1	 in 8.9s
# 		 nIn: 1,	 nOut: 	1	 in 9.0s
# 		 nIn: 1,	 nOut: 	1	 in 9.0s
# 		 nIn: 1,	 nOut: 	1	 in 9.1s
# 		 nIn: 1,	 nOut: 	1	 in 9.2s
# 		 nIn: 1,	 nOut: 	1	 in 9.2s
# 		 nIn: 1,	 nOut: 	1	 in 9.3s
# 		 nIn: 1,	 nOut: 	1	 in 9.3s
# 		 nIn: 1,	 nOut: 	1	 in 9.4s
# 		 nIn: 1,	 nOut: 	1	 in 9.4s
# 		 nIn: 1,	 nOut: 	1	 in 9.5s
# 		 nIn: 1,	 nOut: 	1	 in 9.6s
# 		 nIn: 1,	 nOut: 	1	 in 9.6s
# 		 nIn: 1,	 nOut: 	1	 in 9.7s
# 		 nIn: 1,	 nOut: 	1	 in 9.7s
# 		 nIn: 1,	 nOut: 	1	 in 9.8s
# 		 nIn: 1,	 nOut: 	1	 in 9.9s
# 		 nIn: 1,	 nOut: 	1	 in 9.9s
# 		 nIn: 1,	 nOut: 	1	 in 10.0s
# 		 nIn: 1,	 nOut: 	1	 in 10.0s
# 		 nIn: 1,	 nOut: 	1	 in 10.1s
# 		 nIn: 1,	 nOut: 	1	 in 10.2s
# 		 nIn: 1,	 nOut: 	1	 in 10.2s
# 		 nIn: 1,	 nOut: 	1	 in 10.3s
# 		 nIn: 1,	 nOut: 	1	 in 10.3s
# 		 nIn: 1,	 nOut: 	1	 in 10.4s
# 		 nIn: 1,	 nOut: 	1	 in 10.5s
# 		 nIn: 1,	 nOut: 	1	 in 10.5s
# 		 nIn: 1,	 nOut: 	1	 in 10.6s
# 		 nIn: 1,	 nOut: 	1	 in 10.6s
# 		 nIn: 1,	 nOut: 	1	 in 10.7s
# 		 nIn: 1,	 nOut: 	1	 in 10.8s
# 		 nIn: 1,	 nOut: 	1	 in 10.8s
# 		 nIn: 1,	 nOut: 	1	 in 10.9s
# 		 nIn: 1,	 nOut: 	1	 in 10.9s
# 		 nIn: 1,	 nOut: 	1	 in 11.0s
# 		 nIn: 1,	 nOut: 	1	 in 11.1s
# 		 nIn: 1,	 nOut: 	1	 in 11.1s
# 		 nIn: 1,	 nOut: 	1	 in 11.2s
# 		 nIn: 1,	 nOut: 	1	 in 11.3s
# 		 nIn: 1,	 nOut: 	1	 in 11.3s
# 		 nIn: 1,	 nOut: 	1	 in 11.4s
# 		 nIn: 1,	 nOut: 	1	 in 11.4s
# 		 nIn: 1,	 nOut: 	1	 in 11.5s
# 		 nIn: 1,	 nOut: 	1	 in 11.6s
# 		 nIn: 1,	 nOut: 	1	 in 11.6s
# 		 nIn: 1,	 nOut: 	1	 in 11.7s
# 		 nIn: 1,	 nOut: 	1	 in 11.8s
# 		 nIn: 1,	 nOut: 	1	 in 11.8s
# 		 nIn: 1,	 nOut: 	1	 in 11.9s
# 		 nIn: 1,	 nOut: 	1	 in 11.9s
# 		 nIn: 1,	 nOut: 	1	 in 12.0s
# 		 nIn: 1,	 nOut: 	1	 in 12.1s
# 		 nIn: 1,	 nOut: 	1	 in 12.1s
# 		 nIn: 1,	 nOut: 	1	 in 12.2s
# 		 nIn: 1,	 nOut: 	1	 in 12.3s
# 		 nIn: 1,	 nOut: 	1	 in 12.3s
# 		 nIn: 1,	 nOut: 	1	 in 12.4s
# 		 nIn: 1,	 nOut: 	1	 in 12.5s
# 		 nIn: 1,	 nOut: 	1	 in 12.5s
# 		 nIn: 1,	 nOut: 	1	 in 12.6s
# 		 nIn: 1,	 nOut: 	1	 in 12.7s
# 		 nIn: 1,	 nOut: 	1	 in 12.7s
# 		 nIn: 1,	 nOut: 	1	 in 12.8s
# 		 nIn: 1,	 nOut: 	1	 in 12.9s
# 		 nIn: 1,	 nOut: 	1	 in 12.9s
# 		 nIn: 1,	 nOut: 	1	 in 13.0s
# 		 nIn: 1,	 nOut: 	1	 in 13.1s
# 		 nIn: 1,	 nOut: 	1	 in 13.1s
# 		 nIn: 1,	 nOut: 	1	 in 13.2s
# 		 nIn: 1,	 nOut: 	1	 in 13.3s
# 		 nIn: 1,	 nOut: 	1	 in 13.4s
# 		 nIn: 1,	 nOut: 	1	 in 13.4s
# 		 nIn: 1,	 nOut: 	1	 in 13.5s
# 		 nIn: 1,	 nOut: 	1	 in 13.6s
# 		 nIn: 1,	 nOut: 	1	 in 13.6s
# 		 nIn: 1,	 nOut: 	1	 in 13.7s
# 		 nIn: 1,	 nOut: 	1	 in 13.8s
# 		 nIn: 1,	 nOut: 	1	 in 13.8s
# 		 nIn: 1,	 nOut: 	1	 in 13.9s
# 		 nIn: 1,	 nOut: 	1	 in 14.0s
# 		 nIn: 1,	 nOut: 	1	 in 14.0s
# 		 nIn: 1,	 nOut: 	1	 in 14.1s
# 		 nIn: 1,	 nOut: 	1	 in 14.2s
# 		 nIn: 1,	 nOut: 	1	 in 14.2s
# 		 nIn: 1,	 nOut: 	1	 in 14.3s
# 		 nIn: 1,	 nOut: 	1	 in 14.4s
# 		 nIn: 1,	 nOut: 	1	 in 14.5s
# 		 nIn: 1,	 nOut: 	1	 in 14.5s
# 		 nIn: 1,	 nOut: 	1	 in 14.6s
# 		 nIn: 1,	 nOut: 	1	 in 14.7s
# 		 nIn: 1,	 nOut: 	1	 in 14.7s
# 		 nIn: 1,	 nOut: 	1	 in 14.8s
# 		 nIn: 1,	 nOut: 	1	 in 14.9s
# 		 nIn: 1,	 nOut: 	1	 in 15.0s
# 		 nIn: 1,	 nOut: 	1	 in 15.0s
# 		 nIn: 1,	 nOut: 	1	 in 15.1s
# 		 nIn: 1,	 nOut: 	1	 in 15.2s
# 		 nIn: 1,	 nOut: 	1	 in 15.2s
# 		 nIn: 1,	 nOut: 	1	 in 15.3s
# 		 nIn: 1,	 nOut: 	1	 in 15.4s
# 		 nIn: 1,	 nOut: 	1	 in 15.5s
# 		 nIn: 1,	 nOut: 	1	 in 15.5s
# 		 nIn: 1,	 nOut: 	1	 in 15.6s
# 		 nIn: 1,	 nOut: 	1	 in 15.7s
# 		 nIn: 1,	 nOut: 	1	 in 15.8s
# 		 nIn: 1,	 nOut: 	1	 in 15.8s
# 		 nIn: 1,	 nOut: 	1	 in 15.9s
# 		 nIn: 1,	 nOut: 	1	 in 16.0s
# 		 nIn: 1,	 nOut: 	1	 in 16.1s
# 		 nIn: 1,	 nOut: 	1	 in 16.1s
# 		 nIn: 1,	 nOut: 	1	 in 16.2s
# 		 nIn: 1,	 nOut: 	1	 in 16.3s
# 		 nIn: 1,	 nOut: 	1	 in 16.4s
# 		 nIn: 1,	 nOut: 	1	 in 16.4s
# 		 nIn: 1,	 nOut: 	1	 in 16.5s
# 		 nIn: 1,	 nOut: 	1	 in 16.6s
# 		 nIn: 1,	 nOut: 	1	 in 16.7s
# 		 nIn: 1,	 nOut: 	1	 in 16.7s
# 		 nIn: 1,	 nOut: 	1	 in 16.8s
# 		 nIn: 1,	 nOut: 	1	 in 16.9s
# 		 nIn: 1,	 nOut: 	1	 in 17.0s
# 		 nIn: 1,	 nOut: 	1	 in 17.0s
# 		 nIn: 1,	 nOut: 	1	 in 17.1s
# 		 nIn: 1,	 nOut: 	1	 in 17.2s
# 		 nIn: 1,	 nOut: 	1	 in 17.3s
# 		 nIn: 1,	 nOut: 	1	 in 17.4s
# 		 nIn: 1,	 nOut: 	1	 in 17.4s
# 		 nIn: 1,	 nOut: 	1	 in 17.5s
# 		 nIn: 1,	 nOut: 	1	 in 17.6s
# 		 nIn: 1,	 nOut: 	1	 in 17.7s
# 		 nIn: 1,	 nOut: 	1	 in 17.8s
# 		 nIn: 1,	 nOut: 	1	 in 17.8s
# 		 nIn: 1,	 nOut: 	1	 in 17.9s
# 		 nIn: 1,	 nOut: 	1	 in 18.0s
# 		 nIn: 1,	 nOut: 	1	 in 18.1s
# 		 nIn: 1,	 nOut: 	1	 in 18.2s
# 		 nIn: 1,	 nOut: 	1	 in 18.2s
# 		 nIn: 1,	 nOut: 	1	 in 18.3s
# 		 nIn: 1,	 nOut: 	1	 in 18.4s
# 		 nIn: 1,	 nOut: 	1	 in 18.5s
# 		 nIn: 1,	 nOut: 	1	 in 18.6s
# 		 nIn: 1,	 nOut: 	1	 in 18.6s
# 		 nIn: 1,	 nOut: 	1	 in 18.7s
# 		 nIn: 1,	 nOut: 	1	 in 18.8s
# 		 nIn: 1,	 nOut: 	1	 in 18.9s
# 		 nIn: 1,	 nOut: 	1	 in 19.0s
# 		 nIn: 1,	 nOut: 	1	 in 19.0s
# 		 nIn: 1,	 nOut: 	1	 in 19.1s
# 		 nIn: 1,	 nOut: 	1	 in 19.2s
# 		 nIn: 1,	 nOut: 	1	 in 19.3s
# 		 nIn: 1,	 nOut: 	1	 in 19.4s
# 		 nIn: 1,	 nOut: 	1	 in 19.5s
# 		 nIn: 1,	 nOut: 	1	 in 19.6s
# 		 nIn: 1,	 nOut: 	1	 in 19.6s
# 		 nIn: 1,	 nOut: 	1	 in 19.7s
# 		 nIn: 1,	 nOut: 	1	 in 19.8s
# 		 nIn: 1,	 nOut: 	1	 in 19.9s
# 		 nIn: 1,	 nOut: 	1	 in 20.0s
# 		 nIn: 1,	 nOut: 	1	 in 20.1s
# 		 nIn: 1,	 nOut: 	1	 in 20.2s
# 		 nIn: 1,	 nOut: 	1	 in 20.2s
# 		 nIn: 1,	 nOut: 	1	 in 20.3s
# 		 nIn: 1,	 nOut: 	1	 in 20.4s
# 		 nIn: 1,	 nOut: 	1	 in 20.5s
# 		 nIn: 1,	 nOut: 	1	 in 20.6s
# 		 nIn: 1,	 nOut: 	1	 in 20.7s
# 		 nIn: 1,	 nOut: 	1	 in 20.8s
# 		 nIn: 1,	 nOut: 	1	 in 20.8s
# 		 nIn: 1,	 nOut: 	1	 in 20.9s
# 		 nIn: 1,	 nOut: 	1	 in 21.0s
# 		 nIn: 1,	 nOut: 	1	 in 21.1s
# 		 nIn: 1,	 nOut: 	1	 in 21.2s
# 		 nIn: 1,	 nOut: 	1	 in 21.3s
# 		 nIn: 1,	 nOut: 	1	 in 21.3s
# 		 nIn: 1,	 nOut: 	1	 in 21.4s
# 		 nIn: 1,	 nOut: 	1	 in 21.5s
# 		 nIn: 1,	 nOut: 	1	 in 21.6s
# 		 nIn: 1,	 nOut: 	1	 in 21.7s
# 		 nIn: 1,	 nOut: 	1	 in 21.8s
# 		 nIn: 1,	 nOut: 	1	 in 21.9s
# 		 nIn: 1,	 nOut: 	1	 in 21.9s
# 		 nIn: 1,	 nOut: 	1	 in 22.0s
# 		 nIn: 1,	 nOut: 	1	 in 22.1s
# 		 nIn: 1,	 nOut: 	1	 in 22.2s
# 		 nIn: 1,	 nOut: 	1	 in 22.3s
# 		 nIn: 1,	 nOut: 	1	 in 22.4s
# 		 nIn: 1,	 nOut: 	1	 in 22.5s
# 		 nIn: 1,	 nOut: 	1	 in 22.6s
# 		 nIn: 1,	 nOut: 	1	 in 22.6s
# 		 nIn: 1,	 nOut: 	1	 in 22.7s
# 		 nIn: 1,	 nOut: 	1	 in 22.8s
# 		 nIn: 1,	 nOut: 	1	 in 22.9s
# 		 nIn: 1,	 nOut: 	1	 in 23.0s
# 		 nIn: 1,	 nOut: 	1	 in 23.1s
# 		 nIn: 1,	 nOut: 	1	 in 23.2s
# 		 nIn: 1,	 nOut: 	1	 in 23.3s
# 		 nIn: 1,	 nOut: 	1	 in 23.4s
# 		 nIn: 1,	 nOut: 	1	 in 23.4s
# 		 nIn: 1,	 nOut: 	1	 in 23.5s
# 		 nIn: 1,	 nOut: 	1	 in 23.6s
# 		 nIn: 1,	 nOut: 	1	 in 23.7s
# 		 nIn: 1,	 nOut: 	1	 in 23.8s
# 		 nIn: 1,	 nOut: 	1	 in 23.9s
# 		 nIn: 1,	 nOut: 	1	 in 24.0s
# 		 nIn: 1,	 nOut: 	1	 in 24.1s
# 		 nIn: 1,	 nOut: 	1	 in 24.2s
# Processing Background $Z,t\bar{t}$ samples
# 	Processing: Zee
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.3s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.4s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.5s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.6s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.7s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.8s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 1.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.0s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.1s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.2s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.3s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.4s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.5s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.6s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.7s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.8s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 2.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.0s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.1s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.2s
# 		 nIn: 1,	 nOut: 	1	 in 3.3s
# 		 nIn: 1,	 nOut: 	1	 in 3.3s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.4s
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# 		 nIn: 1,	 nOut: 	1	 in 3.5s
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# 		 nIn: 1,	 nOut: 	1	 in 3.6s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.7s
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# 		 nIn: 1,	 nOut: 	1	 in 3.8s
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# 		 nIn: 1,	 nOut: 	1	 in 3.9s
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# 		 nIn: 1,	 nOut: 	1	 in 4.0s
# 		 nIn: 1,	 nOut: 	1	 in 4.1s
# 		 nIn: 1,	 nOut: 	1	 in 4.1s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.2s
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# 		 nIn: 1,	 nOut: 	1	 in 4.3s
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# 		 nIn: 1,	 nOut: 	1	 in 4.4s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.5s
# 		 nIn: 1,	 nOut: 	1	 in 4.6s
# 		 nIn: 1,	 nOut: 	1	 in 4.6s
# 		 nIn: 1,	 nOut: 	1	 in 4.7s
# 		 nIn: 1,	 nOut: 	1	 in 4.7s
# 		 nIn: 1,	 nOut: 	1	 in 4.7s
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# 		 nIn: 1,	 nOut: 	1	 in 4.8s
# 		 nIn: 1,	 nOut: 	1	 in 4.9s
# 		 nIn: 1,	 nOut: 	1	 in 4.9s
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# 		 nIn: 1,	 nOut: 	1	 in 5.0s
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# 		 nIn: 1,	 nOut: 	1	 in 5.1s
# 		 nIn: 1,	 nOut: 	1	 in 5.2s
# 		 nIn: 1,	 nOut: 	1	 in 5.2s
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# 		 nIn: 1,	 nOut: 	1	 in 5.3s
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# 		 nIn: 1,	 nOut: 	1	 in 5.4s
# 		 nIn: 1,	 nOut: 	1	 in 5.5s
# 		 nIn: 1,	 nOut: 	1	 in 5.5s
# 		 nIn: 1,	 nOut: 	1	 in 5.5s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.6s
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# 		 nIn: 1,	 nOut: 	1	 in 5.7s
# 		 nIn: 1,	 nOut: 	1	 in 5.8s
# 		 nIn: 1,	 nOut: 	1	 in 5.8s
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# 		 nIn: 1,	 nOut: 	1	 in 5.9s
# 		 nIn: 1,	 nOut: 	1	 in 6.0s
# 		 nIn: 1,	 nOut: 	1	 in 6.0s
# 		 nIn: 1,	 nOut: 	1	 in 6.1s
# 		 nIn: 1,	 nOut: 	1	 in 6.1s
# 		 nIn: 1,	 nOut: 	1	 in 6.2s
# 		 nIn: 1,	 nOut: 	1	 in 6.2s
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# 		 nIn: 1,	 nOut: 	1	 in 6.3s
# 		 nIn: 1,	 nOut: 	1	 in 6.4s
# 		 nIn: 1,	 nOut: 	1	 in 6.4s
# 		 nIn: 1,	 nOut: 	1	 in 6.5s
# 		 nIn: 1,	 nOut: 	1	 in 6.5s
# 		 nIn: 1,	 nOut: 	1	 in 6.6s
# 		 nIn: 1,	 nOut: 	1	 in 6.6s
# 		 nIn: 1,	 nOut: 	1	 in 6.7s
# 		 nIn: 1,	 nOut: 	1	 in 6.7s
# 		 nIn: 1,	 nOut: 	1	 in 6.8s
# 		 nIn: 1,	 nOut: 	1	 in 6.8s
# 		 nIn: 1,	 nOut: 	1	 in 6.9s
# 		 nIn: 1,	 nOut: 	1	 in 6.9s
# 		 nIn: 1,	 nOut: 	1	 in 7.0s
# 		 nIn: 1,	 nOut: 	1	 in 7.0s
# 		 nIn: 1,	 nOut: 	1	 in 7.1s
# 		 nIn: 1,	 nOut: 	1	 in 7.1s
# 		 nIn: 1,	 nOut: 	1	 in 7.2s
# 		 nIn: 1,	 nOut: 	1	 in 7.2s
# 		 nIn: 1,	 nOut: 	1	 in 7.3s
# 		 nIn: 1,	 nOut: 	1	 in 7.3s
# 		 nIn: 1,	 nOut: 	1	 in 7.4s
# 		 nIn: 1,	 nOut: 	1	 in 7.4s
# 		 nIn: 1,	 nOut: 	1	 in 7.5s
# 		 nIn: 1,	 nOut: 	1	 in 7.5s
# 		 nIn: 1,	 nOut: 	1	 in 7.6s
# 		 nIn: 1,	 nOut: 	1	 in 7.6s
# 		 nIn: 1,	 nOut: 	1	 in 7.7s
# 		 nIn: 1,	 nOut: 	1	 in 7.8s
# 		 nIn: 1,	 nOut: 	1	 in 7.8s
# 		 nIn: 1,	 nOut: 	1	 in 7.9s
# 		 nIn: 1,	 nOut: 	1	 in 7.9s
# 		 nIn: 1,	 nOut: 	1	 in 8.0s
# 		 nIn: 1,	 nOut: 	1	 in 8.0s
# 		 nIn: 1,	 nOut: 	1	 in 8.1s
# 		 nIn: 1,	 nOut: 	1	 in 8.1s
# 		 nIn: 1,	 nOut: 	1	 in 8.2s
# 		 nIn: 1,	 nOut: 	1	 in 8.2s
# 		 nIn: 1,	 nOut: 	1	 in 8.3s
# 		 nIn: 1,	 nOut: 	1	 in 8.3s
# 		 nIn: 1,	 nOut: 	1	 in 8.4s
# 		 nIn: 1,	 nOut: 	1	 in 8.4s
# 		 nIn: 1,	 nOut: 	1	 in 8.5s
# 		 nIn: 1,	 nOut: 	1	 in 8.6s
# 		 nIn: 1,	 nOut: 	1	 in 8.6s
# 		 nIn: 1,	 nOut: 	1	 in 8.7s
# 		 nIn: 1,	 nOut: 	1	 in 8.7s
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# 		 nIn: 1,	 nOut: 	1	 in 8.8s
# 		 nIn: 1,	 nOut: 	1	 in 8.9s
# 		 nIn: 1,	 nOut: 	1	 in 8.9s
# 		 nIn: 1,	 nOut: 	1	 in 9.0s
# 		 nIn: 1,	 nOut: 	1	 in 9.1s
# 		 nIn: 1,	 nOut: 	1	 in 9.1s
# 		 nIn: 1,	 nOut: 	1	 in 9.2s
# 		 nIn: 1,	 nOut: 	1	 in 9.2s
# 		 nIn: 1,	 nOut: 	1	 in 9.3s
# 		 nIn: 1,	 nOut: 	1	 in 9.3s
# 		 nIn: 1,	 nOut: 	1	 in 9.4s
# 		 nIn: 1,	 nOut: 	1	 in 9.4s
# 		 nIn: 1,	 nOut: 	1	 in 9.5s
# 		 nIn: 1,	 nOut: 	1	 in 9.6s
# 		 nIn: 1,	 nOut: 	1	 in 9.6s
# 		 nIn: 1,	 nOut: 	1	 in 9.7s
# 		 nIn: 1,	 nOut: 	1	 in 9.7s
# 		 nIn: 1,	 nOut: 	1	 in 9.8s
# 		 nIn: 1,	 nOut: 	1	 in 9.9s
# 		 nIn: 1,	 nOut: 	1	 in 9.9s
# 		 nIn: 1,	 nOut: 	1	 in 10.0s
# 		 nIn: 1,	 nOut: 	1	 in 10.0s
# 		 nIn: 1,	 nOut: 	1	 in 10.1s
# 		 nIn: 1,	 nOut: 	1	 in 10.1s
# 		 nIn: 1,	 nOut: 	1	 in 10.2s
# 		 nIn: 1,	 nOut: 	1	 in 10.3s
# 		 nIn: 1,	 nOut: 	1	 in 10.3s
# 		 nIn: 1,	 nOut: 	1	 in 10.4s
# 		 nIn: 1,	 nOut: 	1	 in 10.4s
# 		 nIn: 1,	 nOut: 	1	 in 10.5s
# 		 nIn: 1,	 nOut: 	1	 in 10.6s
# 		 nIn: 1,	 nOut: 	1	 in 10.6s
# 		 nIn: 1,	 nOut: 	1	 in 10.7s
# 		 nIn: 1,	 nOut: 	1	 in 10.7s
# 		 nIn: 1,	 nOut: 	1	 in 10.8s
# 		 nIn: 1,	 nOut: 	1	 in 10.9s
# 		 nIn: 1,	 nOut: 	1	 in 10.9s
# 		 nIn: 1,	 nOut: 	1	 in 11.0s
# 		 nIn: 1,	 nOut: 	1	 in 11.1s
# 		 nIn: 1,	 nOut: 	1	 in 11.1s
# 		 nIn: 1,	 nOut: 	1	 in 11.2s
# 		 nIn: 1,	 nOut: 	1	 in 11.2s
# 		 nIn: 1,	 nOut: 	1	 in 11.3s
# 		 nIn: 1,	 nOut: 	1	 in 11.4s
# 		 nIn: 1,	 nOut: 	1	 in 11.4s
# 		 nIn: 1,	 nOut: 	1	 in 11.5s
# 		 nIn: 1,	 nOut: 	1	 in 11.5s
# 		 nIn: 1,	 nOut: 	1	 in 11.6s
# 		 nIn: 1,	 nOut: 	1	 in 11.7s
# 		 nIn: 1,	 nOut: 	1	 in 11.7s
# 		 nIn: 1,	 nOut: 	1	 in 11.8s
# 		 nIn: 1,	 nOut: 	1	 in 11.9s
# 		 nIn: 1,	 nOut: 	1	 in 11.9s
# 		 nIn: 1,	 nOut: 	1	 in 12.0s
# 		 nIn: 1,	 nOut: 	1	 in 12.1s
# 		 nIn: 1,	 nOut: 	1	 in 12.1s
# 		 nIn: 1,	 nOut: 	1	 in 12.2s
# 		 nIn: 1,	 nOut: 	1	 in 12.2s
# 		 nIn: 1,	 nOut: 	1	 in 12.3s
# 		 nIn: 1,	 nOut: 	1	 in 12.4s
# 		 nIn: 1,	 nOut: 	1	 in 12.4s
# 		 nIn: 1,	 nOut: 	1	 in 12.5s
# 		 nIn: 1,	 nOut: 	1	 in 12.6s
# 		 nIn: 1,	 nOut: 	1	 in 12.6s
# 		 nIn: 1,	 nOut: 	1	 in 12.7s
# 		 nIn: 1,	 nOut: 	1	 in 12.8s
# 		 nIn: 1,	 nOut: 	1	 in 12.8s
# 		 nIn: 1,	 nOut: 	1	 in 12.9s
# 		 nIn: 1,	 nOut: 	1	 in 13.0s
# 		 nIn: 1,	 nOut: 	1	 in 13.0s
# 		 nIn: 1,	 nOut: 	1	 in 13.1s
# 		 nIn: 1,	 nOut: 	1	 in 13.2s
# 		 nIn: 1,	 nOut: 	1	 in 13.2s
# 		 nIn: 1,	 nOut: 	1	 in 13.3s
# 		 nIn: 1,	 nOut: 	1	 in 13.4s
# 		 nIn: 1,	 nOut: 	1	 in 13.4s
# 		 nIn: 1,	 nOut: 	1	 in 13.5s
# 		 nIn: 1,	 nOut: 	1	 in 13.6s
# 		 nIn: 1,	 nOut: 	1	 in 13.6s
# 		 nIn: 1,	 nOut: 	1	 in 13.7s
# 		 nIn: 1,	 nOut: 	1	 in 13.8s
# 		 nIn: 1,	 nOut: 	1	 in 13.8s
# 		 nIn: 1,	 nOut: 	1	 in 13.9s
# 		 nIn: 1,	 nOut: 	1	 in 14.0s
# 		 nIn: 1,	 nOut: 	1	 in 14.0s
# 		 nIn: 1,	 nOut: 	1	 in 14.1s
# 		 nIn: 1,	 nOut: 	1	 in 14.2s
# 		 nIn: 1,	 nOut: 	1	 in 14.2s
# 		 nIn: 1,	 nOut: 	1	 in 14.3s
# 		 nIn: 1,	 nOut: 	1	 in 14.4s
# 		 nIn: 1,	 nOut: 	1	 in 14.5s
# 		 nIn: 1,	 nOut: 	1	 in 14.5s
# 		 nIn: 1,	 nOut: 	1	 in 14.6s
# 		 nIn: 1,	 nOut: 	1	 in 14.7s
# 		 nIn: 1,	 nOut: 	1	 in 14.7s
# 		 nIn: 1,	 nOut: 	1	 in 14.8s
# 		 nIn: 1,	 nOut: 	1	 in 14.9s
# 		 nIn: 1,	 nOut: 	1	 in 15.0s
# 		 nIn: 1,	 nOut: 	1	 in 15.0s
# 		 nIn: 1,	 nOut: 	1	 in 15.1s
# 		 nIn: 1,	 nOut: 	1	 in 15.2s
# 		 nIn: 1,	 nOut: 	1	 in 15.2s
# 		 nIn: 1,	 nOut: 	1	 in 15.3s
# 		 nIn: 1,	 nOut: 	1	 in 15.4s
# 		 nIn: 1,	 nOut: 	1	 in 15.5s
# 		 nIn: 1,	 nOut: 	1	 in 15.5s
# 		 nIn: 1,	 nOut: 	1	 in 15.6s
# 		 nIn: 1,	 nOut: 	1	 in 15.7s
# 		 nIn: 1,	 nOut: 	1	 in 15.8s
# 		 nIn: 1,	 nOut: 	1	 in 15.8s
# 		 nIn: 1,	 nOut: 	1	 in 15.9s
# 		 nIn: 1,	 nOut: 	1	 in 16.0s
# 		 nIn: 1,	 nOut: 	1	 in 16.0s
# 		 nIn: 1,	 nOut: 	1	 in 16.1s
# 		 nIn: 1,	 nOut: 	1	 in 16.2s
# 		 nIn: 1,	 nOut: 	1	 in 16.3s
# 		 nIn: 1,	 nOut: 	1	 in 16.3s
# 		 nIn: 1,	 nOut: 	1	 in 16.4s
# 		 nIn: 1,	 nOut: 	1	 in 16.5s
# 		 nIn: 1,	 nOut: 	1	 in 16.6s
# 		 nIn: 1,	 nOut: 	1	 in 16.6s
# 		 nIn: 1,	 nOut: 	1	 in 16.7s
# 		 nIn: 1,	 nOut: 	1	 in 16.8s
# 		 nIn: 1,	 nOut: 	1	 in 16.9s
# 		 nIn: 1,	 nOut: 	1	 in 16.9s
# 		 nIn: 1,	 nOut: 	1	 in 17.0s
# 		 nIn: 1,	 nOut: 	1	 in 17.1s
# 		 nIn: 1,	 nOut: 	1	 in 17.2s
# 		 nIn: 1,	 nOut: 	1	 in 17.3s
# 		 nIn: 1,	 nOut: 	1	 in 17.3s
# 		 nIn: 1,	 nOut: 	1	 in 17.4s
# 		 nIn: 1,	 nOut: 	1	 in 17.5s
# 		 nIn: 1,	 nOut: 	1	 in 17.6s
# 		 nIn: 1,	 nOut: 	1	 in 17.6s
# 		 nIn: 1,	 nOut: 	1	 in 17.7s
# 		 nIn: 1,	 nOut: 	1	 in 17.8s
# 		 nIn: 1,	 nOut: 	1	 in 17.9s
# 		 nIn: 1,	 nOut: 	1	 in 18.0s
# 		 nIn: 1,	 nOut: 	1	 in 18.0s
# 		 nIn: 1,	 nOut: 	1	 in 18.1s
# 		 nIn: 1,	 nOut: 	1	 in 18.2s
# 		 nIn: 1,	 nOut: 	1	 in 18.3s
# 		 nIn: 1,	 nOut: 	1	 in 18.4s
# 		 nIn: 1,	 nOut: 	1	 in 18.4s
# 		 nIn: 1,	 nOut: 	1	 in 18.5s
# 		 nIn: 1,	 nOut: 	1	 in 18.6s
# 		 nIn: 1,	 nOut: 	1	 in 18.7s
# 		 nIn: 1,	 nOut: 	1	 in 18.8s
# 		 nIn: 1,	 nOut: 	1	 in 18.8s
# 		 nIn: 1,	 nOut: 	1	 in 18.9s
# 		 nIn: 1,	 nOut: 	1	 in 19.0s
# 		 nIn: 1,	 nOut: 	1	 in 19.1s
# 		 nIn: 1,	 nOut: 	1	 in 19.1s
# 		 nIn: 1,	 nOut: 	1	 in 19.2s
# 		 nIn: 1,	 nOut: 	1	 in 19.3s
# 		 nIn: 1,	 nOut: 	1	 in 19.4s
# 		 nIn: 1,	 nOut: 	1	 in 19.5s
# 		 nIn: 1,	 nOut: 	1	 in 19.5s
# 		 nIn: 1,	 nOut: 	1	 in 19.6s
# 		 nIn: 1,	 nOut: 	1	 in 19.7s
# 		 nIn: 1,	 nOut: 	1	 in 19.8s
# 		 nIn: 1,	 nOut: 	1	 in 19.9s
# 		 nIn: 1,	 nOut: 	1	 in 20.0s
# 		 nIn: 1,	 nOut: 	1	 in 20.0s
# 		 nIn: 1,	 nOut: 	1	 in 20.1s
# 		 nIn: 1,	 nOut: 	1	 in 20.2s
# 		 nIn: 1,	 nOut: 	1	 in 20.3s
# 		 nIn: 1,	 nOut: 	1	 in 20.4s
# 		 nIn: 1,	 nOut: 	1	 in 20.5s
# 		 nIn: 1,	 nOut: 	1	 in 20.5s
# 		 nIn: 1,	 nOut: 	1	 in 20.6s
# 		 nIn: 1,	 nOut: 	1	 in 20.7s
# 		 nIn: 1,	 nOut: 	1	 in 20.8s
# 		 nIn: 1,	 nOut: 	1	 in 20.9s
# 		 nIn: 1,	 nOut: 	1	 in 21.0s
# 		 nIn: 1,	 nOut: 	1	 in 21.1s
# 		 nIn: 1,	 nOut: 	1	 in 21.1s
# 		 nIn: 1,	 nOut: 	1	 in 21.2s
# 		 nIn: 1,	 nOut: 	1	 in 21.3s
# 		 nIn: 1,	 nOut: 	1	 in 21.4s
# 		 nIn: 1,	 nOut: 	1	 in 21.5s
# 		 nIn: 1,	 nOut: 	1	 in 21.6s
# 		 nIn: 1,	 nOut: 	1	 in 21.7s
# 		 nIn: 1,	 nOut: 	1	 in 21.8s
# 		 nIn: 1,	 nOut: 	1	 in 21.9s
# 		 nIn: 1,	 nOut: 	1	 in 21.9s
# 		 nIn: 1,	 nOut: 	1	 in 22.0s
# 		 nIn: 1,	 nOut: 	1	 in 22.1s
# 		 nIn: 1,	 nOut: 	1	 in 22.2s
# 		 nIn: 1,	 nOut: 	1	 in 22.3s
# 		 nIn: 1,	 nOut: 	1	 in 22.4s
# 		 nIn: 1,	 nOut: 	1	 in 22.5s
# 		 nIn: 1,	 nOut: 	1	 in 22.6s
# 		 nIn: 1,	 nOut: 	1	 in 22.6s
# 		 nIn: 1,	 nOut: 	1	 in 22.7s
# 		 nIn: 1,	 nOut: 	1	 in 22.8s
# 		 nIn: 1,	 nOut: 	1	 in 22.9s
# 		 nIn: 1,	 nOut: 	1	 in 23.0s
# 		 nIn: 1,	 nOut: 	1	 in 23.1s
# 		 nIn: 1,	 nOut: 	1	 in 23.2s
# 		 nIn: 1,	 nOut: 	1	 in 23.3s
# 		 nIn: 1,	 nOut: 	1	 in 23.4s
# 		 nIn: 1,	 nOut: 	1	 in 23.5s
# 		 nIn: 1,	 nOut: 	1	 in 23.5s
# 		 nIn: 1,	 nOut: 	1	 in 23.6s
# 		 nIn: 1,	 nOut: 	1	 in 23.7s
# 		 nIn: 1,	 nOut: 	1	 in 23.8s
# 		 nIn: 1,	 nOut: 	1	 in 23.9s
# 		 nIn: 1,	 nOut: 	1	 in 24.0s
# 		 nIn: 1,	 nOut: 	1	 in 24.1s
# 		 nIn: 1,	 nOut: 	1	 in 24.2s
# 		 nIn: 1,	 nOut: 	1	 in 24.3s
# 		 nIn: 1,	 nOut: 	1	 in 24.4s
# 		 nIn: 1,	 nOut: 	1	 in 24.5s
# 		 nIn: 1,	 nOut: 	1	 in 24.5s
# 		 nIn: 1,	 nOut: 	1	 in 24.6s
# 		 nIn: 1,	 nOut: 	1	 in 24.7s
# 		 nIn: 1,	 nOut: 	1	 in 24.8s
# 		 nIn: 1,	 nOut: 	1	 in 24.9s
# 		 nIn: 1,	 nOut: 	1	 in 25.0s
# 		 nIn: 1,	 nOut: 	1	 in 25.1s
# 		 nIn: 1,	 nOut: 	1	 in 25.2s
# 		 nIn: 1,	 nOut: 	1	 in 25.3s
# 		 nIn: 1,	 nOut: 	1	 in 25.4s
# 		 nIn: 1,	 nOut: 	1	 in 25.5s
# 		 nIn: 1,	 nOut: 	1	 in 25.6s
# 		 nIn: 1,	 nOut: 	1	 in 25.7s
# 		 nIn: 1,	 nOut: 	1	 in 25.8s
# 		 nIn: 1,	 nOut: 	1	 in 25.8s
# 		 nIn: 1,	 nOut: 	1	 in 25.9s
# 		 nIn: 1,	 nOut: 	1	 in 26.1s
# 		 nIn: 1,	 nOut: 	1	 in 26.2s
# 		 nIn: 1,	 nOut: 	1	 in 26.3s
# 		 nIn: 1,	 nOut: 	1	 in 26.4s
# 		 nIn: 1,	 nOut: 	1	 in 26.5s
# 		 nIn: 1,	 nOut: 	1	 in 26.6s
# 		 nIn: 1,	 nOut: 	1	 in 26.7s
# 		 nIn: 1,	 nOut: 	1	 in 26.8s
# 		 nIn: 1,	 nOut: 	1	 in 26.9s
# 		 nIn: 1,	 nOut: 	1	 in 26.9s
# 		 nIn: 1,	 nOut: 	1	 in 27.0s
# 		 nIn: 1,	 nOut: 	1	 in 27.1s
# 		 nIn: 1,	 nOut: 	1	 in 27.2s
# 		 nIn: 1,	 nOut: 	1	 in 27.3s
# 		 nIn: 1,	 nOut: 	1	 in 27.4s
# 		 nIn: 1,	 nOut: 	1	 in 27.5s
# 		 nIn: 1,	 nOut: 	1	 in 27.6s
# 		 nIn: 1,	 nOut: 	1	 in 27.7s
# 		 nIn: 1,	 nOut: 	1	 in 27.8s
# 		 nIn: 1,	 nOut: 	1	 in 27.9s
# 		 nIn: 1,	 nOut: 	1	 in 28.0s
# 		 nIn: 1,	 nOut: 	1	 in 28.1s
# 		 nIn: 1,	 nOut: 	1	 in 28.2s
# 		 nIn: 1,	 nOut: 	1	 in 28.3s
# 		 nIn: 1,	 nOut: 	1	 in 28.4s
# 		 nIn: 1,	 nOut: 	1	 in 28.5s
# 		 nIn: 1,	 nOut: 	1	 in 28.6s
# 		 nIn: 1,	 nOut: 	1	 in 28.7s
# 		 nIn: 1,	 nOut: 	1	 in 28.8s
# 		 nIn: 1,	 nOut: 	1	 in 28.9s
# 		 nIn: 1,	 nOut: 	1	 in 29.0s
# 		 nIn: 1,	 nOut: 	1	 in 29.1s
# 		 nIn: 1,	 nOut: 	1	 in 29.2s
# 		 nIn: 1,	 nOut: 	1	 in 29.3s
# 		 nIn: 1,	 nOut: 	1	 in 29.4s
# 		 nIn: 1,	 nOut: 	1	 in 29.5s
# 		 nIn: 1,	 nOut: 	1	 in 29.6s
# 		 nIn: 1,	 nOut: 	1	 in 29.7s
# 		 nIn: 1,	 nOut: 	1	 in 29.8s
# 		 nIn: 1,	 nOut: 	1	 in 29.9s
# 		 nIn: 1,	 nOut: 	1	 in 30.0s
# 		 nIn: 1,	 nOut: 	1	 in 30.1s
# 		 nIn: 1,	 nOut: 	1	 in 30.2s
# 		 nIn: 1,	 nOut: 	1	 in 30.3s
# 		 nIn: 1,	 nOut: 	1	 in 30.4s
# 		 nIn: 1,	 nOut: 	1	 in 30.5s
# 		 nIn: 1,	 nOut: 	1	 in 30.6s
# 		 nIn: 1,	 nOut: 	1	 in 30.7s
# 		 nIn: 1,	 nOut: 	1	 in 30.8s
# 		 nIn: 1,	 nOut: 	1	 in 30.9s
# 		 nIn: 1,	 nOut: 	1	 in 31.0s
# 		 nIn: 1,	 nOut: 	1	 in 31.1s
# 		 nIn: 1,	 nOut: 	1	 in 31.2s
# 		 nIn: 1,	 nOut: 	1	 in 31.3s
# 		 nIn: 1,	 nOut: 	1	 in 31.4s
# 		 nIn: 1,	 nOut: 	1	 in 31.5s
# 		 nIn: 1,	 nOut: 	1	 in 31.6s
# 		 nIn: 1,	 nOut: 	1	 in 31.7s
# 		 nIn: 1,	 nOut: 	1	 in 31.8s
# 		 nIn: 1,	 nOut: 	1	 in 31.9s
# 		 nIn: 1,	 nOut: 	1	 in 32.0s
# 		 nIn: 1,	 nOut: 	1	 in 32.1s
# 		 nIn: 1,	 nOut: 	1	 in 32.2s
# 		 nIn: 1,	 nOut: 	1	 in 32.3s
# 		 nIn: 1,	 nOut: 	1	 in 32.4s
# 		 nIn: 1,	 nOut: 	1	 in 32.5s
# 		 nIn: 1,	 nOut: 	1	 in 32.6s
# 		 nIn: 1,	 nOut: 	1	 in 32.7s
# 		 nIn: 1,	 nOut: 	1	 in 32.8s
# 		 nIn: 1,	 nOut: 	1	 in 32.9s
# 		 nIn: 1,	 nOut: 	1	 in 33.0s
# 		 nIn: 1,	 nOut: 	1	 in 33.1s
# 		 nIn: 1,	 nOut: 	1	 in 33.2s
# 		 nIn: 1,	 nOut: 	1	 in 33.3s
# 		 nIn: 1,	 nOut: 	1	 in 33.4s
# 		 nIn: 1,	 nOut: 	1	 in 33.5s
# 		 nIn: 1,	 nOut: 	1	 in 33.7s
# 		 nIn: 1,	 nOut: 	1	 in 33.8s
# 		 nIn: 1,	 nOut: 	1	 in 33.9s
# 		 nIn: 1,	 nOut: 	1	 in 34.0s
# 		 nIn: 1,	 nOut: 	1	 in 34.1s
# 		 nIn: 1,	 nOut: 	1	 in 34.2s
# 		 nIn: 1,	 nOut: 	1	 in 34.3s
# 		 nIn: 1,	 nOut: 	1	 in 34.4s
# 		 nIn: 1,	 nOut: 	1	 in 34.5s
# 		 nIn: 1,	 nOut: 	1	 in 34.6s
# 		 nIn: 1,	 nOut: 	1	 in 34.7s
# 		 nIn: 1,	 nOut: 	1	 in 34.8s
# 		 nIn: 1,	 nOut: 	1	 in 34.9s
# 		 nIn: 1,	 nOut: 	1	 in 35.0s
# 		 nIn: 1,	 nOut: 	1	 in 35.1s
# 		 nIn: 1,	 nOut: 	1	 in 35.3s
# 		 nIn: 1,	 nOut: 	1	 in 35.4s
# 		 nIn: 1,	 nOut: 	1	 in 35.5s
# 		 nIn: 1,	 nOut: 	1	 in 35.6s
# 		 nIn: 1,	 nOut: 	1	 in 35.7s
# 		 nIn: 1,	 nOut: 	1	 in 35.8s
# 		 nIn: 1,	 nOut: 	1	 in 35.9s
# 		 nIn: 1,	 nOut: 	1	 in 36.0s
# 		 nIn: 1,	 nOut: 	1	 in 36.1s
# 		 nIn: 1,	 nOut: 	1	 in 36.2s
# 		 nIn: 1,	 nOut: 	1	 in 36.4s
# 		 nIn: 1,	 nOut: 	1	 in 36.5s
# 		 nIn: 1,	 nOut: 	1	 in 36.6s
# 		 nIn: 1,	 nOut: 	1	 in 36.7s
# 		 nIn: 1,	 nOut: 	1	 in 36.8s
# 		 nIn: 1,	 nOut: 	1	 in 36.9s
# 		 nIn: 1,	 nOut: 	1	 in 37.0s
# 		 nIn: 1,	 nOut: 	1	 in 37.1s
# 		 nIn: 1,	 nOut: 	1	 in 37.3s
# 		 nIn: 1,	 nOut: 	1	 in 37.4s
# 		 nIn: 1,	 nOut: 	1	 in 37.5s
# 		 nIn: 1,	 nOut: 	1	 in 37.6s
# 		 nIn: 1,	 nOut: 	1	 in 37.7s
# 		 nIn: 1,	 nOut: 	1	 in 37.8s
# 		 nIn: 1,	 nOut: 	1	 in 37.9s
# 		 nIn: 1,	 nOut: 	1	 in 38.0s
# 		 nIn: 1,	 nOut: 	1	 in 38.2s
# 		 nIn: 1,	 nOut: 	1	 in 38.3s
# 		 nIn: 1,	 nOut: 	1	 in 38.4s
# 		 nIn: 1,	 nOut: 	1	 in 38.5s
# 		 nIn: 1,	 nOut: 	1	 in 38.6s
# 		 nIn: 1,	 nOut: 	1	 in 38.7s
# 		 nIn: 1,	 nOut: 	1	 in 38.8s
# 		 nIn: 1,	 nOut: 	1	 in 38.9s
# 		 nIn: 1,	 nOut: 	1	 in 39.1s
# 		 nIn: 1,	 nOut: 	1	 in 39.2s
# 		 nIn: 1,	 nOut: 	1	 in 39.3s
# 		 nIn: 1,	 nOut: 	1	 in 39.4s
# 		 nIn: 1,	 nOut: 	1	 in 39.5s
# 		 nIn: 1,	 nOut: 	1	 in 39.6s
# 		 nIn: 1,	 nOut: 	1	 in 39.7s
# 		 nIn: 1,	 nOut: 	1	 in 39.9s
# 		 nIn: 1,	 nOut: 	1	 in 40.0s
# 		 nIn: 1,	 nOut: 	1	 in 40.1s
# 		 nIn: 1,	 nOut: 	1	 in 40.2s
# 		 nIn: 1,	 nOut: 	1	 in 40.3s
# 		 nIn: 1,	 nOut: 	1	 in 40.4s
# 		 nIn: 1,	 nOut: 	1	 in 40.6s
# 		 nIn: 1,	 nOut: 	1	 in 40.7s
# 		 nIn: 1,	 nOut: 	1	 in 40.8s
# 		 nIn: 1,	 nOut: 	1	 in 40.9s
# 		 nIn: 1,	 nOut: 	1	 in 41.0s
# 		 nIn: 1,	 nOut: 	1	 in 41.1s
# 		 nIn: 1,	 nOut: 	1	 in 41.3s
# 		 nIn: 1,	 nOut: 	1	 in 41.4s
# 		 nIn: 1,	 nOut: 	1	 in 41.5s
# 		 nIn: 1,	 nOut: 	1	 in 41.6s
# 		 nIn: 1,	 nOut: 	1	 in 41.7s
# 		 nIn: 1,	 nOut: 	1	 in 41.8s
# 		 nIn: 1,	 nOut: 	1	 in 42.0s
# 		 nIn: 1,	 nOut: 	1	 in 42.1s
# 		 nIn: 1,	 nOut: 	1	 in 42.2s
# 		 nIn: 1,	 nOut: 	1	 in 42.3s
# 		 nIn: 1,	 nOut: 	1	 in 42.4s
# 		 nIn: 1,	 nOut: 	1	 in 42.5s
# 		 nIn: 1,	 nOut: 	1	 in 42.7s
# 		 nIn: 1,	 nOut: 	1	 in 42.8s
# 		 nIn: 1,	 nOut: 	1	 in 42.9s
# 		 nIn: 1,	 nOut: 	1	 in 43.0s
# 		 nIn: 1,	 nOut: 	1	 in 43.1s
# 		 nIn: 1,	 nOut: 	1	 in 43.3s
# 		 nIn: 1,	 nOut: 	1	 in 43.4s
# 		 nIn: 1,	 nOut: 	1	 in 43.5s
# 		 nIn: 1,	 nOut: 	1	 in 43.6s
# 		 nIn: 1,	 nOut: 	1	 in 43.7s
# 		 nIn: 1,	 nOut: 	1	 in 43.9s
# 		 nIn: 1,	 nOut: 	1	 in 44.0s
# 		 nIn: 1,	 nOut: 	1	 in 44.1s
# 		 nIn: 1,	 nOut: 	1	 in 44.2s
# 		 nIn: 1,	 nOut: 	1	 in 44.3s
# 		 nIn: 1,	 nOut: 	1	 in 44.5s
# 		 nIn: 1,	 nOut: 	1	 in 44.6s
# 		 nIn: 1,	 nOut: 	1	 in 44.7s
# 		 nIn: 1,	 nOut: 	1	 in 44.8s
# 		 nIn: 1,	 nOut: 	1	 in 45.0s
# 		 nIn: 1,	 nOut: 	1	 in 45.1s
# 		 nIn: 1,	 nOut: 	1	 in 45.2s
# 		 nIn: 1,	 nOut: 	1	 in 45.3s
# 		 nIn: 1,	 nOut: 	1	 in 45.4s
# 		 nIn: 1,	 nOut: 	1	 in 45.6s
# 		 nIn: 1,	 nOut: 	1	 in 45.7s
# 		 nIn: 1,	 nOut: 	1	 in 45.8s
# 		 nIn: 1,	 nOut: 	1	 in 45.9s
# 		 nIn: 1,	 nOut: 	1	 in 46.1s
# 		 nIn: 1,	 nOut: 	1	 in 46.2s
# 		 nIn: 1,	 nOut: 	1	 in 46.3s
# 		 nIn: 1,	 nOut: 	1	 in 46.4s
# 		 nIn: 1,	 nOut: 	1	 in 46.6s
# 		 nIn: 1,	 nOut: 	1	 in 46.7s
# 		 nIn: 1,	 nOut: 	1	 in 46.8s
# 		 nIn: 1,	 nOut: 	1	 in 46.9s
# 		 nIn: 1,	 nOut: 	1	 in 47.1s
# 		 nIn: 1,	 nOut: 	1	 in 47.2s
# 		 nIn: 1,	 nOut: 	1	 in 47.3s
# 		 nIn: 1,	 nOut: 	1	 in 47.5s
# 		 nIn: 1,	 nOut: 	1	 in 47.6s
# 		 nIn: 1,	 nOut: 	1	 in 47.7s
# 		 nIn: 1,	 nOut: 	1	 in 47.8s
# 		 nIn: 1,	 nOut: 	1	 in 48.0s
# 		 nIn: 1,	 nOut: 	1	 in 48.1s
# 		 nIn: 1,	 nOut: 	1	 in 48.2s
# 		 nIn: 1,	 nOut: 	1	 in 48.4s
# 		 nIn: 1,	 nOut: 	1	 in 48.5s
# 		 nIn: 1,	 nOut: 	1	 in 48.6s
# 		 nIn: 1,	 nOut: 	1	 in 48.7s
# 		 nIn: 1,	 nOut: 	1	 in 48.9s
# 		 nIn: 1,	 nOut: 	1	 in 49.0s
# 		 nIn: 1,	 nOut: 	1	 in 49.1s
# 		 nIn: 1,	 nOut: 	1	 in 49.3s
# 		 nIn: 1,	 nOut: 	1	 in 49.4s
# 		 nIn: 1,	 nOut: 	1	 in 49.5s
# 		 nIn: 1,	 nOut: 	1	 in 49.6s
# 		 nIn: 1,	 nOut: 	1	 in 49.8s
# 		 nIn: 1,	 nOut: 	1	 in 49.9s
# 		 nIn: 1,	 nOut: 	1	 in 50.0s
# 		 nIn: 1,	 nOut: 	1	 in 50.2s
# 		 nIn: 1,	 nOut: 	1	 in 50.3s
# 		 nIn: 1,	 nOut: 	1	 in 50.4s
# 		 nIn: 1,	 nOut: 	1	 in 50.5s
# 		 nIn: 1,	 nOut: 	1	 in 50.7s
# 		 nIn: 1,	 nOut: 	1	 in 50.8s
# 		 nIn: 1,	 nOut: 	1	 in 50.9s
# 		 nIn: 1,	 nOut: 	1	 in 51.1s
# 		 nIn: 1,	 nOut: 	1	 in 51.2s
# 		 nIn: 1,	 nOut: 	1	 in 51.3s
# 		 nIn: 1,	 nOut: 	1	 in 51.5s
# 		 nIn: 1,	 nOut: 	1	 in 51.6s
# 		 nIn: 1,	 nOut: 	1	 in 51.7s
# 		 nIn: 1,	 nOut: 	1	 in 51.8s
# 		 nIn: 1,	 nOut: 	1	 in 52.0s
# 		 nIn: 1,	 nOut: 	1	 in 52.1s
# 		 nIn: 1,	 nOut: 	1	 in 52.2s
# 		 nIn: 1,	 nOut: 	1	 in 52.4s
# 		 nIn: 1,	 nOut: 	1	 in 52.5s
# 		 nIn: 1,	 nOut: 	1	 in 52.6s
# 		 nIn: 1,	 nOut: 	1	 in 52.7s
# 		 nIn: 1,	 nOut: 	1	 in 52.9s
# 		 nIn: 1,	 nOut: 	1	 in 53.0s
# 		 nIn: 1,	 nOut: 	1	 in 53.1s
# 		 nIn: 1,	 nOut: 	1	 in 53.3s
# 		 nIn: 1,	 nOut: 	1	 in 53.4s
# 		 nIn: 1,	 nOut: 	1	 in 53.5s
# 		 nIn: 1,	 nOut: 	1	 in 53.7s
# 		 nIn: 1,	 nOut: 	1	 in 53.8s
# 		 nIn: 1,	 nOut: 	1	 in 53.9s
# 		 nIn: 1,	 nOut: 	1	 in 54.1s
# 		 nIn: 1,	 nOut: 	1	 in 54.2s
# 		 nIn: 1,	 nOut: 	1	 in 54.3s
# 		 nIn: 1,	 nOut: 	1	 in 54.5s
# 		 nIn: 1,	 nOut: 	1	 in 54.6s
# 		 nIn: 1,	 nOut: 	1	 in 54.7s
# 		 nIn: 1,	 nOut: 	1	 in 54.8s
# 		 nIn: 1,	 nOut: 	1	 in 55.0s
# 		 nIn: 1,	 nOut: 	1	 in 55.1s
# 		 nIn: 1,	 nOut: 	1	 in 55.2s
# 		 nIn: 1,	 nOut: 	1	 in 55.4s
# 		 nIn: 1,	 nOut: 	1	 in 55.5s
# 		 nIn: 1,	 nOut: 	1	 in 55.6s
# 		 nIn: 1,	 nOut: 	1	 in 55.8s
# 		 nIn: 1,	 nOut: 	1	 in 55.9s
# 		 nIn: 1,	 nOut: 	1	 in 56.0s
# 		 nIn: 1,	 nOut: 	1	 in 56.2s
# 		 nIn: 1,	 nOut: 	1	 in 56.3s
# 		 nIn: 1,	 nOut: 	1	 in 56.4s
# 		 nIn: 1,	 nOut: 	1	 in 56.6s
# 		 nIn: 1,	 nOut: 	1	 in 56.7s
# 		 nIn: 1,	 nOut: 	1	 in 56.9s
# 		 nIn: 1,	 nOut: 	1	 in 57.0s
# 		 nIn: 1,	 nOut: 	1	 in 57.1s
# 		 nIn: 1,	 nOut: 	1	 in 57.3s
# 		 nIn: 1,	 nOut: 	1	 in 57.4s
# 		 nIn: 1,	 nOut: 	1	 in 57.5s
# 		 nIn: 1,	 nOut: 	1	 in 57.7s
# 		 nIn: 1,	 nOut: 	1	 in 57.8s
# 		 nIn: 1,	 nOut: 	1	 in 57.9s
# 		 nIn: 1,	 nOut: 	1	 in 58.1s
# 		 nIn: 1,	 nOut: 	1	 in 58.2s
# 		 nIn: 1,	 nOut: 	1	 in 58.3s
# 		 nIn: 1,	 nOut: 	1	 in 58.5s
# 		 nIn: 1,	 nOut: 	1	 in 58.6s
# 		 nIn: 1,	 nOut: 	1	 in 58.8s
# 		 nIn: 1,	 nOut: 	1	 in 58.9s
# 		 nIn: 1,	 nOut: 	1	 in 59.0s
# 		 nIn: 1,	 nOut: 	1	 in 59.2s
# 		 nIn: 1,	 nOut: 	1	 in 59.3s
# 		 nIn: 1,	 nOut: 	1	 in 59.4s
# 		 nIn: 1,	 nOut: 	1	 in 59.6s
# 		 nIn: 1,	 nOut: 	1	 in 59.7s
# 		 nIn: 1,	 nOut: 	1	 in 59.9s
# 		 nIn: 1,	 nOut: 	1	 in 60.0s
# 		 nIn: 1,	 nOut: 	1	 in 60.1s
# 		 nIn: 1,	 nOut: 	1	 in 60.3s
# 		 nIn: 1,	 nOut: 	1	 in 60.4s
# 		 nIn: 1,	 nOut: 	1	 in 60.6s
# 		 nIn: 1,	 nOut: 	1	 in 60.7s
# 		 nIn: 1,	 nOut: 	1	 in 60.9s
# 		 nIn: 1,	 nOut: 	1	 in 61.0s
# 		 nIn: 1,	 nOut: 	1	 in 61.1s
# 		 nIn: 1,	 nOut: 	1	 in 61.3s
# 		 nIn: 1,	 nOut: 	1	 in 61.4s
# 		 nIn: 1,	 nOut: 	1	 in 61.6s
# 		 nIn: 1,	 nOut: 	1	 in 61.7s
# 		 nIn: 1,	 nOut: 	1	 in 61.9s
# 		 nIn: 1,	 nOut: 	1	 in 62.0s
# 		 nIn: 1,	 nOut: 	1	 in 62.2s
# 		 nIn: 1,	 nOut: 	1	 in 62.3s
# 		 nIn: 1,	 nOut: 	1	 in 62.5s
# 		 nIn: 1,	 nOut: 	1	 in 62.6s
# 		 nIn: 1,	 nOut: 	1	 in 62.7s
# 		 nIn: 1,	 nOut: 	1	 in 62.9s
# 		 nIn: 1,	 nOut: 	1	 in 63.0s
# 		 nIn: 1,	 nOut: 	1	 in 63.2s
# 		 nIn: 1,	 nOut: 	1	 in 63.3s
# 		 nIn: 1,	 nOut: 	1	 in 63.5s
# 		 nIn: 1,	 nOut: 	1	 in 63.6s
# 		 nIn: 1,	 nOut: 	1	 in 63.7s
# 		 nIn: 1,	 nOut: 	1	 in 63.9s
# 		 nIn: 1,	 nOut: 	1	 in 64.0s
# 		 nIn: 1,	 nOut: 	1	 in 64.2s
# 		 nIn: 1,	 nOut: 	1	 in 64.3s
# 		 nIn: 1,	 nOut: 	1	 in 64.5s
# 		 nIn: 1,	 nOut: 	1	 in 64.6s
# 		 nIn: 1,	 nOut: 	1	 in 64.8s
# ...
# 		 nIn: 1,	 nOut: 	1	 in 38.2s
# 		 nIn: 1,	 nOut: 	1	 in 38.3s
# 		 nIn: 1,	 nOut: 	1	 in 38.4s
# 		 nIn: 1,	 nOut: 	1	 in 38.6s
# 		 nIn: 1,	 nOut: 	1	 in 38.7s
# 		 nIn: 1,	 nOut: 	1	 in 38.8s
# 		 nIn: 1,	 nOut: 	1	 in 38.9s
# 		 nIn: 1,	 nOut: 	1	 in 39.0s
# 		 nIn: 1,	 nOut: 	1	 in 39.1s
# 		 nIn: 1,	 nOut: 	1	 in 39.3s
# 		 nIn: 1,	 nOut: 	1	 in 39.4s
# 		 nIn: 1,	 nOut: 	1	 in 39.5s
# 		 nIn: 1,	 nOut: 	1	 in 39.6s
# 		 nIn: 1,	 nOut: 	1	 in 39.7s
# 		 nIn: 1,	 nOut: 	1	 in 39.8s
# 		 nIn: 1,	 nOut: 	1	 in 39.9s
# 		 nIn: 1,	 nOut: 	1	 in 40.0s
# 		 nIn: 1,	 nOut: 	1	 in 40.2s
# 		 nIn: 1,	 nOut: 	1	 in 40.3s
# 		 nIn: 1,	 nOut: 	1	 in 40.4s
# 		 nIn: 1,	 nOut: 	1	 in 40.5s
# 		 nIn: 1,	 nOut: 	1	 in 40.6s
# 		 nIn: 1,	 nOut: 	1	 in 40.7s
# 		 nIn: 1,	 nOut: 	1	 in 40.8s
# 		 nIn: 1,	 nOut: 	1	 in 40.9s
# 		 nIn: 1,	 nOut: 	1	 in 41.1s
# 		 nIn: 1,	 nOut: 	1	 in 41.2s
# 		 nIn: 1,	 nOut: 	1	 in 41.3s
# 		 nIn: 1,	 nOut: 	1	 in 41.4s
# 		 nIn: 1,	 nOut: 	1	 in 41.5s
# 		 nIn: 1,	 nOut: 	1	 in 41.6s
# 		 nIn: 1,	 nOut: 	1	 in 41.8s
# 		 nIn: 1,	 nOut: 	1	 in 41.9s
# 		 nIn: 1,	 nOut: 	1	 in 42.0s
# 		 nIn: 1,	 nOut: 	1	 in 42.1s
# 		 nIn: 1,	 nOut: 	1	 in 42.2s
# 		 nIn: 1,	 nOut: 	1	 in 42.3s
# 		 nIn: 1,	 nOut: 	1	 in 42.4s
# 		 nIn: 1,	 nOut: 	1	 in 42.6s
# 		 nIn: 1,	 nOut: 	1	 in 42.7s
# 		 nIn: 1,	 nOut: 	1	 in 42.8s
# 		 nIn: 1,	 nOut: 	1	 in 42.9s
# 		 nIn: 1,	 nOut: 	1	 in 43.0s
# 		 nIn: 1,	 nOut: 	1	 in 43.1s
# 		 nIn: 1,	 nOut: 	1	 in 43.3s
# 		 nIn: 1,	 nOut: 	1	 in 43.4s
# 		 nIn: 1,	 nOut: 	1	 in 43.5s
# 		 nIn: 1,	 nOut: 	1	 in 43.6s
# 		 nIn: 1,	 nOut: 	1	 in 43.7s
# 		 nIn: 1,	 nOut: 	1	 in 43.9s
# 		 nIn: 1,	 nOut: 	1	 in 44.0s
# 		 nIn: 1,	 nOut: 	1	 in 44.1s
# 		 nIn: 1,	 nOut: 	1	 in 44.2s
# 		 nIn: 1,	 nOut: 	1	 in 44.4s
# 		 nIn: 1,	 nOut: 	1	 in 44.5s
# 		 nIn: 1,	 nOut: 	1	 in 44.6s
# 		 nIn: 1,	 nOut: 	1	 in 44.7s
# 		 nIn: 1,	 nOut: 	1	 in 44.9s
# 		 nIn: 1,	 nOut: 	1	 in 45.0s
# 		 nIn: 1,	 nOut: 	1	 in 45.1s
# 		 nIn: 1,	 nOut: 	1	 in 45.2s
# 		 nIn: 1,	 nOut: 	1	 in 45.3s
# 		 nIn: 1,	 nOut: 	1	 in 45.5s
# 		 nIn: 1,	 nOut: 	1	 in 45.6s
# 		 nIn: 1,	 nOut: 	1	 in 45.7s
# 		 nIn: 1,	 nOut: 	1	 in 45.8s
# 		 nIn: 1,	 nOut: 	1	 in 45.9s
# 		 nIn: 1,	 nOut: 	1	 in 46.1s
# 		 nIn: 1,	 nOut: 	1	 in 46.2s
# 		 nIn: 1,	 nOut: 	1	 in 46.3s
# 		 nIn: 1,	 nOut: 	1	 in 46.4s
# 		 nIn: 1,	 nOut: 	1	 in 46.6s
# 		 nIn: 1,	 nOut: 	1	 in 46.7s
# 		 nIn: 1,	 nOut: 	1	 in 46.8s
# 		 nIn: 1,	 nOut: 	1	 in 46.9s
# 		 nIn: 1,	 nOut: 	1	 in 47.1s
# 		 nIn: 1,	 nOut: 	1	 in 47.2s
# 		 nIn: 1,	 nOut: 	1	 in 47.3s
# 		 nIn: 1,	 nOut: 	1	 in 47.5s
# 		 nIn: 1,	 nOut: 	1	 in 47.6s
# 		 nIn: 1,	 nOut: 	1	 in 47.7s
# 		 nIn: 1,	 nOut: 	1	 in 47.8s
# 		 nIn: 1,	 nOut: 	1	 in 48.0s
# 		 nIn: 1,	 nOut: 	1	 in 48.1s
# 		 nIn: 1,	 nOut: 	1	 in 48.2s
# 		 nIn: 1,	 nOut: 	1	 in 48.3s
# 		 nIn: 1,	 nOut: 	1	 in 48.5s
# 		 nIn: 1,	 nOut: 	1	 in 48.6s
# 		 nIn: 1,	 nOut: 	1	 in 48.7s
# 		 nIn: 1,	 nOut: 	1	 in 48.8s
# 		 nIn: 1,	 nOut: 	1	 in 49.0s
# 		 nIn: 1,	 nOut: 	1	 in 49.1s
# 		 nIn: 1,	 nOut: 	1	 in 49.2s
# 		 nIn: 1,	 nOut: 	1	 in 49.4s
# 		 nIn: 1,	 nOut: 	1	 in 49.5s
# 		 nIn: 1,	 nOut: 	1	 in 49.6s
# 		 nIn: 1,	 nOut: 	1	 in 49.7s
# 		 nIn: 1,	 nOut: 	1	 in 49.9s
# 		 nIn: 1,	 nOut: 	1	 in 50.0s
# 		 nIn: 1,	 nOut: 	1	 in 50.1s
# 		 nIn: 1,	 nOut: 	1	 in 50.3s
# 		 nIn: 1,	 nOut: 	1	 in 50.4s
# 		 nIn: 1,	 nOut: 	1	 in 50.5s
# 		 nIn: 1,	 nOut: 	1	 in 50.7s
# 		 nIn: 1,	 nOut: 	1	 in 50.8s
# 		 nIn: 1,	 nOut: 	1	 in 50.9s
# 		 nIn: 1,	 nOut: 	1	 in 51.1s
# 		 nIn: 1,	 nOut: 	1	 in 51.2s
# 		 nIn: 1,	 nOut: 	1	 in 51.3s
# 		 nIn: 1,	 nOut: 	1	 in 51.5s
# 		 nIn: 1,	 nOut: 	1	 in 51.6s
# 		 nIn: 1,	 nOut: 	1	 in 51.8s
# 		 nIn: 1,	 nOut: 	1	 in 51.9s
# 		 nIn: 1,	 nOut: 	1	 in 52.0s
# 		 nIn: 1,	 nOut: 	1	 in 52.2s
# 		 nIn: 1,	 nOut: 	1	 in 52.3s
# 		 nIn: 1,	 nOut: 	1	 in 52.4s
# 		 nIn: 1,	 nOut: 	1	 in 52.6s
# 		 nIn: 1,	 nOut: 	1	 in 52.7s
# 		 nIn: 1,	 nOut: 	1	 in 52.8s
# 		 nIn: 1,	 nOut: 	1	 in 53.0s
# 		 nIn: 1,	 nOut: 	1	 in 53.1s
# 		 nIn: 1,	 nOut: 	1	 in 53.2s
# 		 nIn: 1,	 nOut: 	1	 in 53.4s
# 		 nIn: 1,	 nOut: 	1	 in 53.5s
# 		 nIn: 1,	 nOut: 	1	 in 53.6s
# 		 nIn: 1,	 nOut: 	1	 in 53.8s
# 		 nIn: 1,	 nOut: 	1	 in 53.9s
# 		 nIn: 1,	 nOut: 	1	 in 54.0s
# 		 nIn: 1,	 nOut: 	1	 in 54.2s
# 		 nIn: 1,	 nOut: 	1	 in 54.3s
# 		 nIn: 1,	 nOut: 	1	 in 54.4s
# 		 nIn: 1,	 nOut: 	1	 in 54.6s
# 		 nIn: 1,	 nOut: 	1	 in 54.7s
# 		 nIn: 1,	 nOut: 	1	 in 54.8s
# 		 nIn: 1,	 nOut: 	1	 in 55.0s
# 		 nIn: 1,	 nOut: 	1	 in 55.1s
# 		 nIn: 1,	 nOut: 	1	 in 55.3s
# 		 nIn: 1,	 nOut: 	1	 in 55.4s
# 		 nIn: 1,	 nOut: 	1	 in 55.5s
# 		 nIn: 1,	 nOut: 	1	 in 55.7s
# 		 nIn: 1,	 nOut: 	1	 in 55.8s
# 		 nIn: 1,	 nOut: 	1	 in 56.0s
# 		 nIn: 1,	 nOut: 	1	 in 56.1s
# 		 nIn: 1,	 nOut: 	1	 in 56.2s
# 		 nIn: 1,	 nOut: 	1	 in 56.4s
# 		 nIn: 1,	 nOut: 	1	 in 56.5s
# 		 nIn: 1,	 nOut: 	1	 in 56.6s
# 		 nIn: 1,	 nOut: 	1	 in 56.8s
# 		 nIn: 1,	 nOut: 	1	 in 56.9s
# 		 nIn: 1,	 nOut: 	1	 in 57.1s
# 		 nIn: 1,	 nOut: 	1	 in 57.2s
# 		 nIn: 1,	 nOut: 	1	 in 57.3s
# 		 nIn: 1,	 nOut: 	1	 in 57.5s
# 		 nIn: 1,	 nOut: 	1	 in 57.6s
# 		 nIn: 1,	 nOut: 	1	 in 57.7s
# 		 nIn: 1,	 nOut: 	1	 in 57.9s
# 		 nIn: 1,	 nOut: 	1	 in 58.0s
# 		 nIn: 1,	 nOut: 	1	 in 58.2s
# 		 nIn: 1,	 nOut: 	1	 in 58.3s
# 		 nIn: 1,	 nOut: 	1	 in 58.4s
# 		 nIn: 1,	 nOut: 	1	 in 58.6s
# 		 nIn: 1,	 nOut: 	1	 in 58.7s
# 		 nIn: 1,	 nOut: 	1	 in 58.9s
# 		 nIn: 1,	 nOut: 	1	 in 59.0s
# 		 nIn: 1,	 nOut: 	1	 in 59.1s
# 		 nIn: 1,	 nOut: 	1	 in 59.3s
# 		 nIn: 1,	 nOut: 	1	 in 59.4s
# 		 nIn: 1,	 nOut: 	1	 in 59.6s
# 		 nIn: 1,	 nOut: 	1	 in 59.7s
# 		 nIn: 1,	 nOut: 	1	 in 59.8s
# 		 nIn: 1,	 nOut: 	1	 in 60.0s
# 		 nIn: 1,	 nOut: 	1	 in 60.1s
# 		 nIn: 1,	 nOut: 	1	 in 60.3s
# 		 nIn: 1,	 nOut: 	1	 in 60.4s
# 		 nIn: 1,	 nOut: 	1	 in 60.5s
# 		 nIn: 1,	 nOut: 	1	 in 60.7s
# 		 nIn: 1,	 nOut: 	1	 in 60.8s
# 		 nIn: 1,	 nOut: 	1	 in 61.0s
# 		 nIn: 1,	 nOut: 	1	 in 61.1s
# 		 nIn: 1,	 nOut: 	1	 in 61.3s
# 		 nIn: 1,	 nOut: 	1	 in 61.4s
# 		 nIn: 1,	 nOut: 	1	 in 61.6s
# 		 nIn: 1,	 nOut: 	1	 in 61.7s
# 		 nIn: 1,	 nOut: 	1	 in 61.8s
# 		 nIn: 1,	 nOut: 	1	 in 62.0s
# 		 nIn: 1,	 nOut: 	1	 in 62.1s
# 		 nIn: 1,	 nOut: 	1	 in 62.3s
# 		 nIn: 1,	 nOut: 	1	 in 62.4s
# 		 nIn: 1,	 nOut: 	1	 in 62.6s
# 		 nIn: 1,	 nOut: 	1	 in 62.7s
# 		 nIn: 1,	 nOut: 	1	 in 62.9s
# 		 nIn: 1,	 nOut: 	1	 in 63.0s
# 		 nIn: 1,	 nOut: 	1	 in 63.2s
# 		 nIn: 1,	 nOut: 	1	 in 63.3s
# 		 nIn: 1,	 nOut: 	1	 in 63.5s
# 		 nIn: 1,	 nOut: 	1	 in 63.6s
# 		 nIn: 1,	 nOut: 	1	 in 63.8s
# 		 nIn: 1,	 nOut: 	1	 in 63.9s
# 		 nIn: 1,	 nOut: 	1	 in 64.1s
# 		 nIn: 1,	 nOut: 	1	 in 64.2s
# 		 nIn: 1,	 nOut: 	1	 in 64.3s
# 		 nIn: 1,	 nOut: 	1	 in 64.5s
# 		 nIn: 1,	 nOut: 	1	 in 64.6s
# 		 nIn: 1,	 nOut: 	1	 in 64.8s
# 		 nIn: 1,	 nOut: 	1	 in 64.9s
# 		 nIn: 1,	 nOut: 	1	 in 65.1s
# 		 nIn: 1,	 nOut: 	1	 in 65.2s
# 		 nIn: 1,	 nOut: 	1	 in 65.4s
# 		 nIn: 1,	 nOut: 	1	 in 65.5s
# 		 nIn: 1,	 nOut: 	1	 in 65.7s
# 		 nIn: 1,	 nOut: 	1	 in 65.8s
# 		 nIn: 1,	 nOut: 	1	 in 66.0s
# 		 nIn: 1,	 nOut: 	1	 in 66.1s
# 		 nIn: 1,	 nOut: 	1	 in 66.3s
# 		 nIn: 1,	 nOut: 	1	 in 66.4s
# 		 nIn: 1,	 nOut: 	1	 in 66.6s
# 		 nIn: 1,	 nOut: 	1	 in 66.7s
# 		 nIn: 1,	 nOut: 	1	 in 66.9s
# 		 nIn: 1,	 nOut: 	1	 in 67.0s
# 		 nIn: 1,	 nOut: 	1	 in 67.2s
# 		 nIn: 1,	 nOut: 	1	 in 67.3s
# 		 nIn: 1,	 nOut: 	1	 in 67.5s
# 		 nIn: 1,	 nOut: 	1	 in 67.6s
# 		 nIn: 1,	 nOut: 	1	 in 67.8s
# 		 nIn: 1,	 nOut: 	1	 in 67.9s
# 		 nIn: 1,	 nOut: 	1	 in 68.1s
# 		 nIn: 1,	 nOut: 	1	 in 68.2s
# 		 nIn: 1,	 nOut: 	1	 in 68.4s
# 		 nIn: 1,	 nOut: 	1	 in 68.5s
# 		 nIn: 1,	 nOut: 	1	 in 68.7s
# 		 nIn: 1,	 nOut: 	1	 in 68.8s
# 		 nIn: 1,	 nOut: 	1	 in 69.0s
# 		 nIn: 1,	 nOut: 	1	 in 69.1s
# 		 nIn: 1,	 nOut: 	1	 in 69.3s
# 		 nIn: 1,	 nOut: 	1	 in 69.4s
# 		 nIn: 1,	 nOut: 	1	 in 69.5s
# 		 nIn: 1,	 nOut: 	1	 in 69.7s
# 		 nIn: 1,	 nOut: 	1	 in 69.8s
# 		 nIn: 1,	 nOut: 	1	 in 70.0s
# 		 nIn: 1,	 nOut: 	1	 in 70.1s
# 		 nIn: 1,	 nOut: 	1	 in 70.3s
# 		 nIn: 1,	 nOut: 	1	 in 70.4s
# 		 nIn: 1,	 nOut: 	1	 in 70.6s
# 		 nIn: 1,	 nOut: 	1	 in 70.7s
# 		 nIn: 1,	 nOut: 	1	 in 70.9s
# 		 nIn: 1,	 nOut: 	1	 in 71.0s
# 		 nIn: 1,	 nOut: 	1	 in 71.2s
# 		 nIn: 1,	 nOut: 	1	 in 71.4s
# 		 nIn: 1,	 nOut: 	1	 in 71.5s
# 		 nIn: 1,	 nOut: 	1	 in 71.7s
# 		 nIn: 1,	 nOut: 	1	 in 71.8s
# 		 nIn: 1,	 nOut: 	1	 in 72.0s
# 		 nIn: 1,	 nOut: 	1	 in 72.1s
# 		 nIn: 1,	 nOut: 	1	 in 72.3s
# 		 nIn: 1,	 nOut: 	1	 in 72.4s
# 		 nIn: 1,	 nOut: 	1	 in 72.6s
# 		 nIn: 1,	 nOut: 	1	 in 72.7s
# 		 nIn: 1,	 nOut: 	1	 in 72.9s
# 		 nIn: 1,	 nOut: 	1	 in 73.0s
# 		 nIn: 1,	 nOut: 	1	 in 73.2s
# 		 nIn: 1,	 nOut: 	1	 in 73.3s
# 		 nIn: 1,	 nOut: 	1	 in 73.5s
# 		 nIn: 1,	 nOut: 	1	 in 73.6s
# 		 nIn: 1,	 nOut: 	1	 in 73.8s
# 		 nIn: 1,	 nOut: 	1	 in 73.9s
# 		 nIn: 1,	 nOut: 	1	 in 74.1s
# 		 nIn: 1,	 nOut: 	1	 in 74.3s
# 		 nIn: 1,	 nOut: 	1	 in 74.4s
# 		 nIn: 1,	 nOut: 	1	 in 74.6s
# 		 nIn: 1,	 nOut: 	1	 in 74.7s
# 		 nIn: 1,	 nOut: 	1	 in 74.9s
# 		 nIn: 1,	 nOut: 	1	 in 75.0s
# 		 nIn: 1,	 nOut: 	1	 in 75.2s
# 		 nIn: 1,	 nOut: 	1	 in 75.3s
# 		 nIn: 1,	 nOut: 	1	 in 75.5s
# 		 nIn: 1,	 nOut: 	1	 in 75.6s
# 		 nIn: 1,	 nOut: 	1	 in 75.8s
# 		 nIn: 1,	 nOut: 	1	 in 76.0s
# 		 nIn: 1,	 nOut: 	1	 in 76.1s
# 		 nIn: 1,	 nOut: 	1	 in 76.3s
# 		 nIn: 1,	 nOut: 	1	 in 76.4s
# 		 nIn: 1,	 nOut: 	1	 in 76.6s
# 		 nIn: 1,	 nOut: 	1	 in 76.7s
# 		 nIn: 1,	 nOut: 	1	 in 76.9s
# 		 nIn: 1,	 nOut: 	1	 in 77.1s
# 		 nIn: 1,	 nOut: 	1	 in 77.2s
# 		 nIn: 1,	 nOut: 	1	 in 77.4s
# 		 nIn: 1,	 nOut: 	1	 in 77.5s
# 		 nIn: 1,	 nOut: 	1	 in 77.7s
# 		 nIn: 1,	 nOut: 	1	 in 77.8s
# 		 nIn: 1,	 nOut: 	1	 in 78.0s
# 		 nIn: 1,	 nOut: 	1	 in 78.1s
# 		 nIn: 1,	 nOut: 	1	 in 78.3s
# 		 nIn: 1,	 nOut: 	1	 in 78.5s
# 		 nIn: 1,	 nOut: 	1	 in 78.6s
# 		 nIn: 1,	 nOut: 	1	 in 78.8s
# 		 nIn: 1,	 nOut: 	1	 in 78.9s
# 		 nIn: 1,	 nOut: 	1	 in 79.1s
# 		 nIn: 1,	 nOut: 	1	 in 79.3s
# 		 nIn: 1,	 nOut: 	1	 in 79.4s
# 		 nIn: 1,	 nOut: 	1	 in 79.6s
# 		 nIn: 1,	 nOut: 	1	 in 79.7s
# 		 nIn: 1,	 nOut: 	1	 in 79.9s
# 		 nIn: 1,	 nOut: 	1	 in 80.0s
# 		 nIn: 1,	 nOut: 	1	 in 80.2s
# 		 nIn: 1,	 nOut: 	1	 in 80.4s
# 		 nIn: 1,	 nOut: 	1	 in 80.6s
# 		 nIn: 1,	 nOut: 	1	 in 80.8s
# 		 nIn: 1,	 nOut: 	1	 in 80.9s
# 		 nIn: 1,	 nOut: 	1	 in 81.1s
# 		 nIn: 1,	 nOut: 	1	 in 81.3s
# 		 nIn: 1,	 nOut: 	1	 in 81.4s
# 		 nIn: 1,	 nOut: 	1	 in 81.6s
# 		 nIn: 1,	 nOut: 	1	 in 81.8s
# 		 nIn: 1,	 nOut: 	1	 in 82.0s
# 		 nIn: 1,	 nOut: 	1	 in 82.1s
# 		 nIn: 1,	 nOut: 	1	 in 82.3s
# 		 nIn: 1,	 nOut: 	1	 in 82.5s
# 		 nIn: 1,	 nOut: 	1	 in 82.6s
# 		 nIn: 1,	 nOut: 	1	 in 82.8s
# 		 nIn: 1,	 nOut: 	1	 in 83.0s
# 		 nIn: 1,	 nOut: 	1	 in 83.1s
# 		 nIn: 1,	 nOut: 	1	 in 83.3s
# 		 nIn: 1,	 nOut: 	1	 in 83.5s
# 		 nIn: 1,	 nOut: 	1	 in 83.6s
# 		 nIn: 1,	 nOut: 	1	 in 83.8s
# 		 nIn: 1,	 nOut: 	1	 in 84.0s
# 		 nIn: 1,	 nOut: 	1	 in 84.1s
# 		 nIn: 1,	 nOut: 	1	 in 84.3s
# 		 nIn: 1,	 nOut: 	1	 in 84.5s
# 		 nIn: 1,	 nOut: 	1	 in 84.6s
# 		 nIn: 1,	 nOut: 	1	 in 84.8s
# 		 nIn: 1,	 nOut: 	1	 in 85.0s
# 		 nIn: 1,	 nOut: 	1	 in 85.1s
# 		 nIn: 1,	 nOut: 	1	 in 85.3s
# 		 nIn: 1,	 nOut: 	1	 in 85.5s
# 		 nIn: 1,	 nOut: 	1	 in 85.7s
# 		 nIn: 1,	 nOut: 	1	 in 85.9s
# 		 nIn: 1,	 nOut: 	1	 in 86.1s
# 		 nIn: 1,	 nOut: 	1	 in 86.3s
# 		 nIn: 1,	 nOut: 	1	 in 86.4s
# 		 nIn: 1,	 nOut: 	1	 in 86.6s
# 		 nIn: 1,	 nOut: 	1	 in 86.8s
# 		 nIn: 1,	 nOut: 	1	 in 87.0s
# 		 nIn: 1,	 nOut: 	1	 in 87.2s
# 		 nIn: 1,	 nOut: 	1	 in 87.3s
# 		 nIn: 1,	 nOut: 	1	 in 87.5s
# 		 nIn: 1,	 nOut: 	1	 in 87.7s
# 		 nIn: 1,	 nOut: 	1	 in 87.8s
# 		 nIn: 1,	 nOut: 	1	 in 88.0s
# 		 nIn: 1,	 nOut: 	1	 in 88.2s
# 		 nIn: 1,	 nOut: 	1	 in 88.3s
# 		 nIn: 1,	 nOut: 	1	 in 88.5s
# 		 nIn: 1,	 nOut: 	1	 in 88.7s
# 		 nIn: 1,	 nOut: 	1	 in 88.9s
# 		 nIn: 1,	 nOut: 	1	 in 89.1s
# 		 nIn: 1,	 nOut: 	1	 in 89.2s
# 		 nIn: 1,	 nOut: 	1	 in 89.4s
# 		 nIn: 1,	 nOut: 	1	 in 89.6s
# 		 nIn: 1,	 nOut: 	1	 in 89.8s
# 		 nIn: 1,	 nOut: 	1	 in 89.9s
# 		 nIn: 1,	 nOut: 	1	 in 90.1s
# 		 nIn: 1,	 nOut: 	1	 in 90.3s
# 		 nIn: 1,	 nOut: 	1	 in 90.5s
# 		 nIn: 1,	 nOut: 	1	 in 90.6s
# 		 nIn: 1,	 nOut: 	1	 in 90.8s
# 		 nIn: 1,	 nOut: 	1	 in 91.0s
# 		 nIn: 1,	 nOut: 	1	 in 91.2s
# 		 nIn: 1,	 nOut: 	1	 in 91.3s
# 		 nIn: 1,	 nOut: 	1	 in 91.5s
# 		 nIn: 1,	 nOut: 	1	 in 91.7s
# 		 nIn: 1,	 nOut: 	1	 in 91.9s
# 		 nIn: 1,	 nOut: 	1	 in 92.0s
# 		 nIn: 1,	 nOut: 	1	 in 92.2s
# 		 nIn: 1,	 nOut: 	1	 in 92.4s
# 		 nIn: 1,	 nOut: 	1	 in 92.6s
# 		 nIn: 1,	 nOut: 	1	 in 92.7s
# 		 nIn: 1,	 nOut: 	1	 in 92.9s
# 		 nIn: 1,	 nOut: 	1	 in 93.1s
# 		 nIn: 1,	 nOut: 	1	 in 93.2s
# 		 nIn: 1,	 nOut: 	1	 in 93.4s
# 		 nIn: 1,	 nOut: 	1	 in 93.6s
# 		 nIn: 1,	 nOut: 	1	 in 93.8s
# 		 nIn: 1,	 nOut: 	1	 in 93.9s
# 		 nIn: 1,	 nOut: 	1	 in 94.1s
# 		 nIn: 1,	 nOut: 	1	 in 94.3s
# 		 nIn: 1,	 nOut: 	1	 in 94.5s
# 		 nIn: 1,	 nOut: 	1	 in 94.6s
# 		 nIn: 1,	 nOut: 	1	 in 94.8s
# 		 nIn: 1,	 nOut: 	1	 in 95.0s
# 		 nIn: 1,	 nOut: 	1	 in 95.2s
# 		 nIn: 1,	 nOut: 	1	 in 95.3s
# 		 nIn: 1,	 nOut: 	1	 in 95.5s
# 		 nIn: 1,	 nOut: 	1	 in 95.7s
# 		 nIn: 1,	 nOut: 	1	 in 95.9s
# 		 nIn: 1,	 nOut: 	1	 in 96.0s
# 		 nIn: 1,	 nOut: 	1	 in 96.2s
# 		 nIn: 1,	 nOut: 	1	 in 96.4s
# 		 nIn: 1,	 nOut: 	1	 in 96.5s
# 		 nIn: 1,	 nOut: 	1	 in 96.7s
# 		 nIn: 1,	 nOut: 	1	 in 96.9s
# 		 nIn: 1,	 nOut: 	1	 in 97.1s
# 		 nIn: 1,	 nOut: 	1	 in 97.2s
# 		 nIn: 1,	 nOut: 	1	 in 97.4s
# 		 nIn: 1,	 nOut: 	1	 in 97.6s
# 		 nIn: 1,	 nOut: 	1	 in 97.8s
# 		 nIn: 1,	 nOut: 	1	 in 97.9s
# 		 nIn: 1,	 nOut: 	1	 in 98.1s
# 		 nIn: 1,	 nOut: 	1	 in 98.3s
# 		 nIn: 1,	 nOut: 	1	 in 98.5s
# 		 nIn: 1,	 nOut: 	1	 in 98.6s
# 		 nIn: 1,	 nOut: 	1	 in 98.8s
# 		 nIn: 1,	 nOut: 	1	 in 99.0s
# 		 nIn: 1,	 nOut: 	1	 in 99.2s
# 		 nIn: 1,	 nOut: 	1	 in 99.4s
# 		 nIn: 1,	 nOut: 	1	 in 99.5s
# 		 nIn: 1,	 nOut: 	1	 in 99.7s
# 		 nIn: 1,	 nOut: 	1	 in 99.9s
# 		 nIn: 1,	 nOut: 	1	 in 100.1s
# 		 nIn: 1,	 nOut: 	1	 in 100.2s
# 		 nIn: 1,	 nOut: 	1	 in 100.4s
# 		 nIn: 1,	 nOut: 	1	 in 100.6s
# 		 nIn: 1,	 nOut: 	1	 in 100.8s
# 		 nIn: 1,	 nOut: 	1	 in 101.0s
# 		 nIn: 1,	 nOut: 	1	 in 101.1s
# 		 nIn: 1,	 nOut: 	1	 in 101.3s
# 		 nIn: 1,	 nOut: 	1	 in 101.5s
# 		 nIn: 1,	 nOut: 	1	 in 101.7s
# 		 nIn: 1,	 nOut: 	1	 in 101.9s
# 		 nIn: 1,	 nOut: 	1	 in 102.0s
# 		 nIn: 1,	 nOut: 	1	 in 102.2s
# 		 nIn: 1,	 nOut: 	1	 in 102.4s
# 		 nIn: 1,	 nOut: 	1	 in 102.6s
# 		 nIn: 1,	 nOut: 	1	 in 102.8s
# 		 nIn: 1,	 nOut: 	1	 in 102.9s
# 		 nIn: 1,	 nOut: 	1	 in 103.1s
# 		 nIn: 1,	 nOut: 	1	 in 103.3s
# 		 nIn: 1,	 nOut: 	1	 in 103.5s
# 		 nIn: 1,	 nOut: 	1	 in 103.7s
# 		 nIn: 1,	 nOut: 	1	 in 103.8s
# 		 nIn: 1,	 nOut: 	1	 in 104.0s
# 		 nIn: 1,	 nOut: 	1	 in 104.2s
# 		 nIn: 1,	 nOut: 	1	 in 104.4s
# 		 nIn: 1,	 nOut: 	1	 in 104.6s
# 		 nIn: 1,	 nOut: 	1	 in 104.7s
# 		 nIn: 1,	 nOut: 	1	 in 104.9s
# 		 nIn: 1,	 nOut: 	1	 in 105.1s
# 		 nIn: 1,	 nOut: 	1	 in 105.3s
# 		 nIn: 1,	 nOut: 	1	 in 105.5s
# 		 nIn: 1,	 nOut: 	1	 in 105.7s
# 		 nIn: 1,	 nOut: 	1	 in 105.8s
# 		 nIn: 1,	 nOut: 	1	 in 106.0s
# 		 nIn: 1,	 nOut: 	1	 in 106.2s
# 		 nIn: 1,	 nOut: 	1	 in 106.4s
# 		 nIn: 1,	 nOut: 	1	 in 106.6s
# 		 nIn: 1,	 nOut: 	1	 in 106.8s
# 		 nIn: 1,	 nOut: 	1	 in 106.9s
# 		 nIn: 1,	 nOut: 	1	 in 107.1s
# 		 nIn: 1,	 nOut: 	1	 in 107.3s
# 		 nIn: 1,	 nOut: 	1	 in 107.5s
# 		 nIn: 1,	 nOut: 	1	 in 107.7s
# 		 nIn: 1,	 nOut: 	1	 in 107.9s
# 		 nIn: 1,	 nOut: 	1	 in 108.0s
# 		 nIn: 1,	 nOut: 	1	 in 108.2s
# 		 nIn: 1,	 nOut: 	1	 in 108.4s
# 		 nIn: 1,	 nOut: 	1	 in 108.6s
# 		 nIn: 1,	 nOut: 	1	 in 108.8s
# 		 nIn: 1,	 nOut: 	1	 in 109.0s
# 		 nIn: 1,	 nOut: 	1	 in 109.2s
# 		 nIn: 1,	 nOut: 	1	 in 109.3s
# 		 nIn: 1,	 nOut: 	1	 in 109.5s
# 		 nIn: 1,	 nOut: 	1	 in 109.7s
# 		 nIn: 1,	 nOut: 	1	 in 109.9s
# 		 nIn: 1,	 nOut: 	1	 in 110.1s
# 		 nIn: 1,	 nOut: 	1	 in 110.3s
# 		 nIn: 1,	 nOut: 	1	 in 110.5s
# 		 nIn: 1,	 nOut: 	1	 in 110.6s
# 		 nIn: 1,	 nOut: 	1	 in 110.8s
# 		 nIn: 1,	 nOut: 	1	 in 111.0s
# 		 nIn: 1,	 nOut: 	1	 in 111.2s
# 		 nIn: 1,	 nOut: 	1	 in 111.4s
# 		 nIn: 1,	 nOut: 	1	 in 111.6s
# 		 nIn: 1,	 nOut: 	1	 in 111.7s
# 		 nIn: 1,	 nOut: 	1	 in 111.9s
# 		 nIn: 1,	 nOut: 	1	 in 112.1s
# 		 nIn: 1,	 nOut: 	1	 in 112.3s
# 		 nIn: 1,	 nOut: 	1	 in 112.5s
# 		 nIn: 1,	 nOut: 	1	 in 112.7s
# 		 nIn: 1,	 nOut: 	1	 in 112.9s
# 		 nIn: 1,	 nOut: 	1	 in 113.1s
# 		 nIn: 1,	 nOut: 	1	 in 113.3s
# 		 nIn: 1,	 nOut: 	1	 in 113.4s
# 		 nIn: 1,	 nOut: 	1	 in 113.6s
# 		 nIn: 1,	 nOut: 	1	 in 113.8s
# 		 nIn: 1,	 nOut: 	1	 in 114.0s
# 		 nIn: 1,	 nOut: 	1	 in 114.2s
# 		 nIn: 1,	 nOut: 	1	 in 114.4s
# 		 nIn: 1,	 nOut: 	1	 in 114.6s
# Processing Background $ZZ^*$ samples
# 	Processing: llll
# 		 nIn: 554279,	 nOut: 	554279	 in 90.3s
# Processing Signal ($m_H$ = 125 GeV) samples
# 	Processing: ggH125_ZZ4lep
# 		 nIn: 164716,	 nOut: 	164716	 in 32.1s
# 	Processing: VBFH125_ZZ4lep
# 		 nIn: 191126,	 nOut: 	191126	 in 48.5s
# 	Processing: WH125_ZZ4lep
# 		 nIn: 15379,	 nOut: 	15379	 in 5.2s
# 	Processing: ZH125_ZZ4lep
# 		 nIn: 14485,	 nOut: 	14485	 in 12.1s
# Time taken: 576.5s

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='plotting'></a>

# %% [markdown]
# ## Plotting
# If you only want to make a change in plotting: Cell -> Run All Below
#
# Define function to plot the data

# %%
def plot_data(data):

    xmin = 80 * GeV
    xmax = 250 * GeV
    step_size = 5 * GeV

    bin_edges = np.arange(start=xmin, # The interval includes this value
                     stop=xmax+step_size, # The interval doesn't include this value
                     step=step_size ) # Spacing between values
    bin_centres = np.arange(start=xmin+step_size/2, # The interval includes this value
                            stop=xmax+step_size/2, # The interval doesn't include this value
                            step=step_size ) # Spacing between values

    data_x,_ = np.histogram(data['data']['mllll'].to_numpy(), bins=bin_edges ) # histogram the data
    data_x_errors = np.sqrt( data_x ) # statistical error on the data

    signal_x = data[r'Signal ($m_H$ = 125 GeV)']['mllll'].to_numpy() # histogram the signal
    signal_weights = data[r'Signal ($m_H$ = 125 GeV)'].totalWeight.to_numpy() # get the weights of the signal events
    signal_color = samples[r'Signal ($m_H$ = 125 GeV)']['color'] # get the colour for the signal bar

    mc_x = [] # define list to hold the Monte Carlo histogram entries
    mc_weights = [] # define list to hold the Monte Carlo weights
    mc_colors = [] # define list to hold the colors of the Monte Carlo bars
    mc_labels = [] # define list to hold the legend labels of the Monte Carlo bars

    for s in samples: # loop over samples
        if s not in ['data', r'Signal ($m_H$ = 125 GeV)']: # if not data nor signal
            mc_x.append( data[s]['mllll'].to_numpy() ) # append to the list of Monte Carlo histogram entries
            mc_weights.append( data[s].totalWeight.to_numpy() ) # append to the list of Monte Carlo weights
            mc_colors.append( samples[s]['color'] ) # append to the list of Monte Carlo bar colors
            mc_labels.append( s ) # append to the list of Monte Carlo legend labels
    


    # *************
    # Main plot 
    # *************
    main_axes = plt.gca() # get current axes
    
    # plot the data points
    main_axes.errorbar(x=bin_centres, y=data_x, yerr=data_x_errors, fmt='ko', label='Data') 
    
    # plot the Monte Carlo bars
    mc_heights = main_axes.hist(mc_x, bins=bin_edges, 
                                weights=mc_weights, stacked=True, 
                                color=mc_colors, label=mc_labels )
    
    mc_x_tot = mc_heights[0][-1] # stacked background MC y-axis value
    
    # calculate MC statistical uncertainty: sqrt(sum w^2)
    mc_x_err = np.sqrt(np.histogram(np.hstack(mc_x), bins=bin_edges, weights=np.hstack(mc_weights)**2)[0])
    
    # plot the signal bar
    main_axes.hist(signal_x, bins=bin_edges, bottom=mc_x_tot, weights=signal_weights, color=signal_color, label=r'Signal ($m_H$ = 125 GeV)')
    
    # plot the statistical uncertainty
    main_axes.bar(bin_centres, 2*mc_x_err, alpha=0.5, bottom=mc_x_tot-mc_x_err, color='none', hatch="////", width=step_size, label='Stat. Unc.' )

    # set the x-limit of the main axes
    main_axes.set_xlim( left=xmin, right=xmax ) 
    
    # separation of x axis minor ticks
    main_axes.xaxis.set_minor_locator( AutoMinorLocator() ) 
    
    # set the axis tick parameters for the main axes
    main_axes.tick_params(which='both', direction='in', top=True, right=True )
    
    # x-axis label
    main_axes.set_xlabel(r'4-lepton invariant mass $\mathrm{m_{4l}}$ [GeV]', fontsize=13, x=1, horizontalalignment='right' )
    
    # write y-axis label for main axes
    main_axes.set_ylabel('Events / '+str(step_size)+' GeV', y=1, horizontalalignment='right') 
    
    # set y-axis limits for main axes
    main_axes.set_ylim( bottom=0, top=np.amax(data_x)*1.6 )
    
    # add minor ticks on y-axis for main axes
    main_axes.yaxis.set_minor_locator( AutoMinorLocator() ) 

    # Add text 'ATLAS Open Data' on plot
    plt.text(0.05, 0.93, 'ATLAS Open Data', transform=main_axes.transAxes, fontsize=13 ) 
    
    # Add text 'for education' on plot
    plt.text(0.05, 0.88, 'for education', transform=main_axes.transAxes, style='italic', fontsize=8 ) 
    
    # Add energy and luminosity
    lumi_used = str(lumi*fraction) # luminosity to write on the plot
    plt.text(0.05, 0.82, '$\sqrt{s}$=13 TeV,$\int$L dt = '+lumi_used+' fb$^{-1}$', transform=main_axes.transAxes ) # coordinate system used is that of main_axes
    
    # Add a label for the analysis carried out
    plt.text(0.05, 0.76, r'$H \rightarrow ZZ^* \rightarrow 4\ell$', transform=main_axes.transAxes ) # coordinate system used is that of main_axes

    # draw the legend
    main_axes.legend( frameon=False ) # no box around the legend
    
    return

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# Call the function to plot the data

# %%
plot_data(data)

# %% [markdown]
# [Back to contents](#contents)

# %% [markdown]
# <a id='going_further'></a>

# %% [markdown]
# ## What can you do to explore this analysis?
#
# * Increase the fraction of data used in '[Lumi, fraction, file path](#fraction)'
# * Check how many events are being thrown away by each cut in '[Applying a cut](#applying_cut)'
# * Add more cuts from the [Higgs discovery paper](https://www.sciencedirect.com/science/article/pii/S037026931200857X#se0040) in '[Changing a cut](#changing_cut)' and '[Applying a cut](#applying_cut)'
# * Add a plot to show the ratio between Data and MC other than Higgs
# * Add a plot to show the invariant mass distribution of the sub-leading lepton pair, like [Figure 1 of the Higgs discovery paper](https://www.sciencedirect.com/science/article/pii/S037026931200857X#fg0010)
# * Get the estimated numbers of events, like [Table 3 of the Higgs discovery paper](https://www.sciencedirect.com/science/article/pii/S037026931200857X#tl0030)
# * Add a plot of m12 against m34, like [Figure 3 of the Higgs discovery paper](https://www.sciencedirect.com/science/article/pii/S037026931200857X#fg0030)
# * Your idea!

# %% [markdown]
# [Back to contents](#contents)
